# %%
import requests
from api_keys import rapid_api_key

# %%
#This function extracts temperature data for Dec-Feb from the dataset and converts it to Fahrenheit

def extract_temperature_data(weather_data):
    temperature_data = []
    
    # Extract temperature data for December, January, and February
    for data_point in weather_data['data']:
        date = data_point['date']
        tavg_celsius = data_point['tavg']
        tmin_celsius = data_point['tmin']
        tmax_celsius = data_point['tmax']
        
        # Check if any temperature value is None
        if tavg_celsius is None or tmin_celsius is None or tmax_celsius is None:
            continue
        
        # Extract month from date
        month = int(date.split('-')[1])
        
        # Check if month is December, January, or February
        if month in [12, 1, 2]:
            # Convert Celsius to Fahrenheit and round to two decimal places
            tavg_fahrenheit = round((tavg_celsius * 9/5) + 32, 2)
            tmin_fahrenheit = round((tmin_celsius * 9/5) + 32, 2)
            tmax_fahrenheit = round((tmax_celsius * 9/5) + 32, 2)
            
            temperature_data.append({
                'date': date,
                'tavg_fahrenheit': tavg_fahrenheit,
                'tmin_fahrenheit': tmin_fahrenheit,
                'tmax_fahrenheit': tmax_fahrenheit
            })
    
    return temperature_data

# %%
#This is the API function to pull down the weather data. Input Lat/lon of the requested city to get the weather data.
#make sure to set up your api_keys file before running this function

def get_weather_data(lat, lon):
    url = "https://meteostat.p.rapidapi.com/point/daily"

    querystring = {
        "lat": str(lat),
        "lon": str(lon),
        "start": "2011-01-01",
        "end": "2020-02-31",
        "alt": "184"
    }

    headers = {
        "X-RapidAPI-Key": rapid_api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    weather_data = response.json()

    return weather_data

# %%
#function test
data = get_weather_data(50, 50)

# %%
#function test
tempdata = extract_temperature_data(data)

# %%
#test
print(tempdata)
# Out:
# [{'date': '2011-01-01', 'tavg_fahrenheit': 24.8, 'tmin_fahrenheit': 22.82, 'tmax_fahrenheit': 26.06}, {'date': '2011-01-02', 'tavg_fahrenheit': 24.26, 'tmin_fahrenheit': 22.64, 'tmax_fahrenheit': 27.68}, {'date': '2011-01-03', 'tavg_fahrenheit': 24.08, 'tmin_fahrenheit': 17.24, 'tmax_fahrenheit': 30.2}, {'date': '2011-01-04', 'tavg_fahrenheit': 16.52, 'tmin_fahrenheit': 13.82, 'tmax_fahrenheit': 31.1}, {'date': '2011-01-05', 'tavg_fahrenheit': 20.48, 'tmin_fahrenheit': 11.84, 'tmax_fahrenheit': 26.6}, {'date': '2011-01-06', 'tavg_fahrenheit': 19.22, 'tmin_fahrenheit': 15.26, 'tmax_fahrenheit': 25.7}, {'date': '2011-01-07', 'tavg_fahrenheit': 14.36, 'tmin_fahrenheit': 14.72, 'tmax_fahrenheit': 18.68}, {'date': '2011-01-08', 'tavg_fahrenheit': 7.88, 'tmin_fahrenheit': 6.26, 'tmax_fahrenheit': 14.72}, {'date': '2011-01-09', 'tavg_fahrenheit': 3.56, 'tmin_fahrenheit': 2.48, 'tmax_fahrenheit': 14.36}, {'date': '2011-01-10', 'tavg_fahrenheit': 2.3, 'tmin_fahrenheit': -6.88, 'tmax_fahrenheit': 16.16}, {'date': '2011-01-11', 'tavg_fahrenheit': 3.02, 'tmin_fahrenheit': -6.88, 'tmax_fahrenheit': 16.88}, {'date': '2011-01-12', 'tavg_fahrenheit': 6.8, 'tmin_fahrenheit': -1.3, 'tmax_fahrenheit': 19.94}, {'date': '2011-01-13', 'tavg_fahrenheit': 8.6, 'tmin_fahrenheit': -0.76, 'tmax_fahrenheit': 20.66}, {'date': '2011-01-14', 'tavg_fahrenheit': 13.64, 'tmin_fahrenheit': 2.84, 'tmax_fahrenheit': 26.24}, {'date': '2011-01-15', 'tavg_fahrenheit': 17.96, 'tmin_fahrenheit': 14.36, 'tmax_fahrenheit': 25.88}, {'date': '2011-01-16', 'tavg_fahrenheit': 19.4, 'tmin_fahrenheit': 13.64, 'tmax_fahrenheit': 26.06}, {'date': '2011-01-17', 'tavg_fahrenheit': 20.66, 'tmin_fahrenheit': 14.18, 'tmax_fahrenheit': 24.44}, {'date': '2011-01-18', 'tavg_fahrenheit': 12.02, 'tmin_fahrenheit': 13.46, 'tmax_fahrenheit': 20.66}, {'date': '2011-01-19', 'tavg_fahrenheit': 1.4, 'tmin_fahrenheit': 1.4, 'tmax_fahrenheit': 8.42}, {'date': '2011-01-20', 'tavg_fahrenheit': -6.88, 'tmin_fahrenheit': -14.26, 'tmax_fahrenheit': -0.94}, {'date': '2011-01-21', 'tavg_fahrenheit': -1.48, 'tmin_fahrenheit': -7.78, 'tmax_fahrenheit': 8.96}, {'date': '2011-01-22', 'tavg_fahrenheit': -12.1, 'tmin_fahrenheit': -19.48, 'tmax_fahrenheit': -3.64}, {'date': '2011-01-23', 'tavg_fahrenheit': 3.02, 'tmin_fahrenheit': -12.46, 'tmax_fahrenheit': 8.24}, {'date': '2011-01-24', 'tavg_fahrenheit': 15.98, 'tmin_fahrenheit': 2.48, 'tmax_fahrenheit': 15.8}, {'date': '2011-01-25', 'tavg_fahrenheit': 22.1, 'tmin_fahrenheit': 13.64, 'tmax_fahrenheit': 26.06}, {'date': '2011-01-26', 'tavg_fahrenheit': 17.24, 'tmin_fahrenheit': 8.42, 'tmax_fahrenheit': 23.36}, {'date': '2011-01-27', 'tavg_fahrenheit': 16.52, 'tmin_fahrenheit': 10.76, 'tmax_fahrenheit': 26.24}, {'date': '2011-01-28', 'tavg_fahrenheit': 9.68, 'tmin_fahrenheit': -0.4, 'tmax_fahrenheit': 19.4}, {'date': '2011-01-29', 'tavg_fahrenheit': 12.56, 'tmin_fahrenheit': 3.2, 'tmax_fahrenheit': 17.06}, {'date': '2011-01-30', 'tavg_fahrenheit': 18.5, 'tmin_fahrenheit': 9.14, 'tmax_fahrenheit': 25.34}, {'date': '2011-01-31', 'tavg_fahrenheit': 21.2, 'tmin_fahrenheit': 13.1, 'tmax_fahrenheit': 28.76}, {'date': '2011-02-01', 'tavg_fahrenheit': 15.62, 'tmin_fahrenheit': 12.92, 'tmax_fahrenheit': 21.2}, {'date': '2011-02-02', 'tavg_fahrenheit': -1.12, 'tmin_fahrenheit': -3.28, 'tmax_fahrenheit': 8.96}, {'date': '2011-02-03', 'tavg_fahrenheit': -7.42, 'tmin_fahrenheit': -17.68, 'tmax_fahrenheit': 4.28}, {'date': '2011-02-04', 'tavg_fahrenheit': 12.74, 'tmin_fahrenheit': -7.24, 'tmax_fahrenheit': 19.94}, {'date': '2011-02-05', 'tavg_fahrenheit': 22.46, 'tmin_fahrenheit': 17.96, 'tmax_fahrenheit': 24.44}, {'date': '2011-02-06', 'tavg_fahrenheit': 27.86, 'tmin_fahrenheit': 23.54, 'tmax_fahrenheit': 30.74}, {'date': '2011-02-07', 'tavg_fahrenheit': 23.18, 'tmin_fahrenheit': 21.02, 'tmax_fahrenheit': 26.96}, {'date': '2011-02-08', 'tavg_fahrenheit': 19.76, 'tmin_fahrenheit': 8.24, 'tmax_fahrenheit': 26.24}, {'date': '2011-02-09', 'tavg_fahrenheit': 24.62, 'tmin_fahren ...

# %%
type(tempdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(tempdata)
#
# NameError: name 'tempdata' is not defined
