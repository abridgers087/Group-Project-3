# %%
import requests
from api_keys import rapid_api_key
import json
import os

# %%
#This function extracts temperature data for Dec-Feb from the dataset and converts it to Fahrenheit
def extract_temperature_data(weather_data):
    temperature_data = []
    
    # Extract temperature data for December, January, and February
    for data_point in weather_data['data']:
        date = data_point['date']
        tavg_celsius = data_point['tavg']
        tmin_celsius = data_point['tmin']
        tmax_celsius = data_point['tmax']
        
        # Check if any temperature value is None
        if tavg_celsius is None or tmin_celsius is None or tmax_celsius is None:
            continue
        
        # Extract month from date
        month = int(date.split('-')[1])
        
        # Check if month is December, January, or February
        if month in [12, 1, 2]:
            # Convert Celsius to Fahrenheit and round to two decimal places
            tavg_fahrenheit = round((tavg_celsius * 9/5) + 32, 2)
            tmin_fahrenheit = round((tmin_celsius * 9/5) + 32, 2)
            tmax_fahrenheit = round((tmax_celsius * 9/5) + 32, 2)
            
            temperature_data.append({
                'date': date,
                'tavg_fahrenheit': tavg_fahrenheit,
                'tmin_fahrenheit': tmin_fahrenheit,
                'tmax_fahrenheit': tmax_fahrenheit
            })
    
    return temperature_data

# %%
#This is the API function to pull down the weather data. Input Lat/lon of the requested city to get the weather data.
#make sure to set up your api_keys file before running this function
def get_weather_data(lat, lon):
    url = "https://meteostat.p.rapidapi.com/point/daily"

    querystring = {
        "lat": str(lat),
        "lon": str(lon),
        "start": "2011-01-01",
        "end": "2020-02-29",
        #"alt": "184"
    }

    headers = {
        "X-RapidAPI-Key": rapid_api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    weather_data = response.json()

    return weather_data

# %%
def export_data_to_json(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

def export_datasets(datasets):
    data_folder = 'data'

    # Create 'data' folder if it doesn't exist
    if not os.path.exists(data_folder):
        os.makedirs(data_folder)

    for dataset_name, dataset in datasets.items():
        filename = os.path.join(data_folder, f"{dataset_name}_data.json")
        export_data_to_json(dataset, filename)

# %%
#get data
la = get_weather_data(34, 118)
chi = get_weather_data(41, 87)
detroit = get_weather_data(42, 83)
milwaukee = get_weather_data(43, 87)

#empty sets, need better coords
nyc = get_weather_data(40, 73)
columbus = get_weather_data(40, 83)
philly = get_weather_data(39, 75)
newark = get_weather_data(40, 74)
houston = get_weather_data(29, 95)
indianapolis = get_weather_data(39, 86)
milwaukee = get_weather_data(43, 87)

# %%
# Out:
# {'meta': {'generated': '2023-07-07 01:47:12', 'stations': ['38627']},
#  'data': []}

# %%
chi
# Out:
# {'meta': {'generated': '2023-07-07 01:47:13', 'stations': ['51765', '51656']},
#  'data': [{'date': '2011-01-01',
#    'tavg': -12.8,
#    'tmin': -20.2,
#    'tmax': -2.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-02',
#    'tavg': -11.5,
#    'tmin': -17.2,
#    'tmax': -5.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-03',
#    'tavg': -16.1,
#    'tmin': -23.4,
#    'tmax': -8.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-04',
#    'tavg': -15.4,
#    'tmin': -22.7,
#    'tmax': -6.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-05',
#    'tavg': -14.0,
#    'tmin': -21.3,
#    'tmax': -7.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-06',
#    'tavg': -16.1,
#    'tmin': -22.9,
#    'tmax': -7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-07',
#    'tavg': -16.7,
#    'tmin': -23.5,
#    'tmax': -7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-08',
#    'tavg': -16.0,
#    'tmin': -24.2,
#    'tmax': -6.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-09',
#    'tavg': -16.5,
#    'tmin': -25.0,
#    'tmax': -7.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-10',
#    'tavg': -17.0,
#    'tmin': -24.3,
#    'tmax': -8.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-11',
#    'tavg': -17.0,
#    'tmin': -23.6,
#    'tmax': -8.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-12',
#    'tavg': -15.7,
#    'tmin': -23.9,
#    'tmax': -5.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-13',
#    'tavg': -16.1,
#    'tmin': -24.3,
#    'tmax': -5.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-14',
#    'tavg': -11.4,
#    'tmin': -19.1,
#    'tmax': -2.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-15',
#    'tavg': -15.3,
#    'tmin': -23.2,
#    'tmax': -5.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-16',
#    'tavg': -15.6,
#    'tmin': -24.1,
#    'tmax': -4.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-17',
#    'tavg': -14.0,
#    'tmin': -20.8,
#    'tmax': -5.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-18',
#    'tavg': -13.0,
#    'tmin': -17.6,
#    'tmax': -5.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-19',
#    'tavg': -12.6,
#    'tmin': -18.6,
#    'tmax': -3.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-20',
#    'tavg': -13.6,
#    'tmin': -21.3,
#    'tmax': -3.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-21',
#    'tavg': -13.5,
#    'tmin': -21.7,
#    'tmax': -2.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-22',
#    'tavg': -13.3,
#    'tmin': -21.4,
#    'tmax': -2.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-23',
#    'tavg': -11.0,
#    'tmin': -20.6,
#    'tmax': -0.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-24',
#    'tavg': -11.4,
#    'tmin': -19.5,
#    'tmax': -1.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-25',
#    'tavg': -12.0,
#    'tmin': -20.1,
#    'tmax': -1.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-26',
#    'tavg': -11.8,
#    'tmin': -21.6,
#    'tmax': -1.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-27',
#    'tavg': -10.0,
#    'tmin': -16.1,
#    'tmax': -3.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-28',
#    'tavg': -13.5,
#    'tmin': -22.6,
#    'tmax': -2.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-29',
#    'tavg': -12.7,
#    'tmin': -20.9,
#    'tmax': -2.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-30',
#    'tavg': -13.3,
#    'tmin': -22.7,
#    'tmax': -2.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-31',
#    'tavg': -11.8,
#    'tmin': -20.5,
#    'tmax': -1.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-01',
#    'tavg': -8.1,
#    'tmin': -17.1,
#    'tmax': 0.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-02',
#    'tavg': -8.4,
#    'tmin': -18.8,
#    'tmax': 3.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-03',
#    'tavg': -6.5,
#    'tmin': -14.1,
#    'tmax': 0.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-04',
#    'tavg': -6.2,
#    'tmin': -14.6,
#    'tmax': 3.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-05',
#    'tavg': -5.7,
#    'tmin': -13.3,
#    'tmax': 3.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-06',
#    'tavg': -2.9,
#    'tmin': -11.1,
#    'tmax': 7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-07',
#    'tavg': -0.9,
#    'tmin': -7.7,
#    'tmax': 6.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-08',
#    'tavg': 0.4,
#    'tmin': -5.8,
#    'tmax': 6.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-09',
#    'tavg': -1.6,
#    'tmin': -11.6,
#    'tmax': 9.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-10',
#    'tavg': 1.7,
#    'tmin': -2.1,
#    'tmax': 7.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-11',
#    'tavg': -1.9,
#    'tmin': -9.4,
#    'tmax': 7.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-12',
#    'tavg': -2.4,
#    'tmin': -11.4,
#    'tmax': 7.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-13',
#    'tavg': -3.9,
#    'tmin': -12.6,
#    'tmax': 5.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-14',
#    'tavg': -0.3,
#    'tmin': -7.1,
#    'tmax': 8.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-15',
#    'tavg': -0.5,
#    'tmin': -8.4,
#    'tmax': 10.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-16',
#    'tavg': -0.8,
#    'tmin': -10.8,
#    'tmax': 9.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-17',
#    'tavg': 0.1,
#    'tmin': -8.7,
#    'tmax': 10.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-18',
#    'tavg': 1.3,
#    'tmin': -6.5,
#    'tmax': 11.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-19',
#    'tavg': -0.6,
#    'tmin': -11.3,
#    'tmax': 11.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-20',
#    'tavg': 0.6,
#    'tmin': -9.8,
#    'tmax': 10.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-21',
#    'tavg': 2.8,
#    'tmin': -4.7,
#    'tmax': 12.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-22',
#    'tavg': 2.0,
#    'tmin': -8.2,
#    'tmax': 13.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-23',
#    'tavg': 2.8,
#    'tmin': -4.4,
#    'tmax': 13.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-24',
#    'tavg': 4.0,
#    'tmin': -4.0,
#    'tmax': 13.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-25',
#    'tavg': 2.5,
#    'tmin': -2.2,
#    'tmax': 9.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-26',
#    'tavg': 0.9,
#    'tmin': -4.6,
#    'tmax': 5.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-27',
#    'tavg': 0.2,
#    'tmin': -4.5,
#    'tmax': 4.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-28',
#    'tavg': -3.7,
#    'tmin': -12.1,
#    'tmax': 5.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-01',
#    'tavg': -2.7,
#    'tmin': -11.1,
#    'tmax': 6.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-02',
#    'tavg': 0.2,
#    'tmin': -7.3,
#    'tmax': 7.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-03',
#    'tavg': -0.2,
#    'tmin': -6.0,
#    'tmax': 7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-04',
#    'tavg': -1.4,
#    'tmin': -9.4,
#    'tmax': 7.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-05',
#    'tavg': 1.5,
#    'tmin': -5.7,
#    'tmax': 9.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-06',
#    'tavg': 1.3,
#    'tmin': -7.8,
#    'tmax': 10.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-07',
#    'tavg': 2.0,
#    'tmin': -7.3,
#    'tmax': 12.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-08',
#    'tavg': 4.2,
#    'tmin': -6.9,
#    'tmax': 13.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-09',
#    'tavg': 4.7,
#    'tmin': -4.6,
#    'tmax': 13.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-10',
#    'tavg': 5.3,
#    'tmin': -4.1,
#    'tmax': 14.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-11',
#    'tavg': 7.2,
#    'tmin': -2.8,
#    'tmax': 16.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-12',
#    'tavg': 3.7,
#    'tmin': 0.4,
#    'tmax': 13.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-13',
#    'tavg': 1.0,
#    'tmin': -3.7,
#    'tmax': 6.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-14',
#    'tavg': -1.2,
#    'tmin': -9.3,
#    'tmax': 7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-15',
#    'tavg': 1.2,
#    'tmin': -5.8,
#    'tmax': 9.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-16',
#    'tavg': 2.2,
#    'tmin': -4.9,
#    'tmax': 8.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-17',
#    'tavg': 2.1,
#    'tmin': -1.3,
#    'tmax': 6.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-18',
#    'tavg': 1.4,
#    'tmin': -5.6,
#    'tmax': 8.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-19',
#    'tavg': 3.8,
#    'tmin': -2.0,
#    'tmax': 10.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-20',
#    'tavg': -1.0,
#    'tmin': -5.0,
#    'tmax': 7.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-21',
#    'tavg': -3.2,
#    'tmin': -11.6,
#    'tmax': 5.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-22',
#    'tavg': -1.7,
#    'tmin': -10.5,
#    'tmax': 7.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-23',
#    'tavg': 0.5,
#    'tmin': -7.6,
#    'tmax': 8.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-24',
#    'tavg': 2.2,
#    'tmin': -6.7,
#    'tmax': 11.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-25',
#    'tavg': 3.2,
#    'tmin': -6.9,
#    'tmax': 13.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-26',
#    'tavg': 5.0,
#    'tmin': -5.6,
#    'tmax': 16.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-27',
#    'tavg': 8.9,
#    'tmin': -2.2,
#    'tmax': 19.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-28',
#    'tavg': 11.5,
#    'tmin': 0.6,
#    'tmax': 21.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-29',
#    'tavg': 9.9,
#    'tmin': -1.0,
#    'tmax': 20.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-30',
#    'tavg': 11.6,
#    'tmin': 2.7,
#    'tmax': 21.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-31',
#    'tavg': 12.9,
#    'tmin': 4.9,
#    'tmax': 21.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-01',
#    'tavg': 14.1,
#    'tmin': 6.4,
#    'tmax': 22.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-02',
#    'tavg': 15.1,
#    'tmin': 7.4,
#    'tmax': 22.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-03',
#    'tavg': 14.5,
#    'tmin': 4.2,
#    'tmax': 22.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-04',
#    'tavg': 11.6,
#    'tmin': 4.7,
#    'tmax': 20.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-05',
#    'tavg': 5.4,
#    'tmin': 1.8,
#    'tmax': 14.9,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-06',
#    'tavg': 5.7,
#    'tmin': -1.5,
#    'tmax': 12.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-07',
#    'tavg': 8.1,
#    'tmin': 1.9,
#    'tmax': 15.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-08',
#    'tavg': 9.7,
#    'tmin': 0.5,
#    'tmax': 19.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-09',
#    'tavg': 12.6,
#    'tmin': 1.2,
#    'tmax': 22.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-10',
#    'tavg': 12.8,
#    'tmin': 0.5,
#    'tmax': 24.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-11',
#    'tavg': 14.3,
#    'tmin': 2.2,
#    'tmax': 25.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-12',
#    'tavg': 16.9,
#    'tmin': 7.9,
#    'tmax': 26.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-13',
#    'tavg': 16.6,
#    'tmin': 4.4,
#    'tmax': 27.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-14',
#    'tavg': 17.3,
#    'tmin': 4.9,
#    'tmax': 28.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-15',
#    'tavg': 20.6,
#    'tmin': 9.8,
#    'tmax': 30.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-16',
#    'tavg': 20.8,
#    'tmin': 8.5,
#    'tmax': 31.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-17',
#    'tavg': 24.1,
#    'tmin': 17.0,
#    'tmax': 30.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-18',
#    'tavg': 23.6,
#    'tmin': 19.6,
#    'tmax': 28.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-19',
#    'tavg': 21.0,
#    'tmin': 13.3,
#    'tmax': 26.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-20',
#    'tavg': 20.1,
#    'tmin': 12.5,
#    'tmax': 28.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-21',
#    'tavg': 19.7,
#    'tmin': 10.7,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-22',
#    'tavg': 19.3,
#    'tmin': 8.8,
#    'tmax': 28.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-23',
#    'tavg': 20.0,
#    'tmin': 11.1,
#    'tmax': 28.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-24',
#    'tavg': 19.5,
#    'tmin': 7.0,
#    'tmax': 32.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-25',
#    'tavg': 24.8,
#    'tmin': 12.8,
#    'tmax': 34.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-26',
#    'tavg': 24.2,
#    'tmin': 9.7,
#    'tmax': 36.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-27',
#    'tavg': 26.1,
#    'tmin': 14.2,
#    'tmax': 36.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-28',
#    'tavg': 23.4,
#    'tmin': 11.9,
#    'tmax': 37.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-29',
#    'tavg': 19.3,
#    'tmin': 11.8,
#    'tmax': 25.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-30',
#    'tavg': 16.7,
#    'tmin': 6.8,
#    'tmax': 23.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-01',
#    'tavg': 19.4,
#    'tmin': 10.7,
#    'tmax': 28.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-02',
#    'tavg': 19.7,
#    'tmin': 13.7,
#    'tmax': 25.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-03',
#    'tavg': 20.5,
#    'tmin': 10.3,
#    'tmax': 30.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-04',
#    'tavg': 22.8,
#    'tmin': 15.5,
#    'tmax': 33.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-05',
#    'tavg': 23.3,
#    'tmin': 12.3,
#    'tmax': 34.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-06',
#    'tavg': 26.3,
#    'tmin': 21.4,
#    'tmax': 31.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-07',
#    'tavg': 24.0,
#    'tmin': 17.9,
#    'tmax': 29.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-08',
#    'tavg': 20.1,
#    'tmin': 13.2,
#    'tmax': 25.7,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-09',
#    'tavg': 16.8,
#    'tmin': 11.1,
#    'tmax': 23.8,
#    'prcp': 3.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-10',
#    'tavg': 16.4,
#    'tmin': 10.6,
#    'tmax': 22.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-11',
#    'tavg': 17.6,
#    'tmin': 8.2,
#    'tmax': 25.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-12',
#    'tavg': 20.2,
#    'tmin': 10.4,
#    'tmax': 27.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-13',
#    'tavg': 20.3,
#    'tmin': 10.6,
#    'tmax': 29.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-14',
#    'tavg': 21.4,
#    'tmin': 9.1,
#    'tmax': 30.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-15',
#    'tavg': 23.1,
#    'tmin': 10.1,
#    'tmax': 34.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-16',
#    'tavg': 25.5,
#    'tmin': 14.4,
#    'tmax': 36.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-17',
#    'tavg': 27.1,
#    'tmin': 14.3,
#    'tmax': 39.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-18',
#    'tavg': 24.7,
#    'tmin': 16.7,
#    'tmax': 34.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-19',
#    'tavg': 19.6,
#    'tmin': 17.1,
#    'tmax': 29.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-20',
#    'tavg': 20.9,
#    'tmin': 15.4,
#    'tmax': 27.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-21',
#    'tavg': 18.1,
#    'tmin': 13.0,
#    'tmax': 23.4,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-22',
#    'tavg': 18.9,
#    'tmin': 8.6,
#    'tmax': 27.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-23',
#    'tavg': 20.6,
#    'tmin': 8.6,
#    'tmax': 28.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-24',
#    'tavg': 21.6,
#    'tmin': 11.9,
#    'tmax': 30.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-25',
#    'tavg': 21.7,
#    'tmin': 9.2,
#    'tmax': 32.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-26',
#    'tavg': 24.1,
#    'tmin': 11.4,
#    'tmax': 35.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-27',
#    'tavg': 24.3,
#    'tmin': 14.3,
#    'tmax': 31.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-28',
#    'tavg': 20.4,
#    'tmin': 15.9,
#    'tmax': 27.1,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-29',
#    'tavg': 19.5,
#    'tmin': 6.7,
#    'tmax': 30.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-30',
#    'tavg': 22.2,
#    'tmin': 7.7,
#    'tmax': 33.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-31',
#    'tavg': 22.8,
#    'tmin': 12.1,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-01',
#    'tavg': 24.8,
#    'tmin': 14.0,
#    'tmax': 35.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-02',
#    'tavg': 24.9,
#    'tmin': 20.0,
#    'tmax': 32.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-03',
#    'tavg': 24.6,
#    'tmin': 19.0,
#    'tmax': 29.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-04',
#    'tavg': 23.5,
#    'tmin': 11.5,
#    'tmax': 33.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-05',
#    'tavg': 26.4,
#    'tmin': 13.9,
#    'tmax': 36.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-06',
#    'tavg': 27.4,
#    'tmin': 17.6,
#    'tmax': 36.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-07',
#    'tavg': 26.0,
#    'tmin': 19.1,
#    'tmax': 32.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-08',
#    'tavg': 25.3,
#    'tmin': 19.2,
#    'tmax': 31.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-09',
#    'tavg': 24.8,
#    'tmin': 12.4,
#    'tmax': 34.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-10',
#    'tavg': 27.9,
#    'tmin': 17.7,
#    'tmax': 35.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-11',
#    'tavg': 27.4,
#    'tmin': 14.7,
#    'tmax': 35.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-12',
#    'tavg': 29.6,
#    'tmin': 18.1,
#    'tmax': 39.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-13',
#    'tavg': 28.6,
#    'tmin': 18.9,
#    'tmax': 39.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-14',
#    'tavg': 31.9,
#    'tmin': 28.0,
#    'tmax': 34.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-15',
#    'tavg': 22.3,
#    'tmin': 19.6,
#    'tmax': 30.8,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-16',
#    'tavg': 22.9,
#    'tmin': 16.3,
#    'tmax': 33.1,
#    'prcp': 2.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-17',
#    'tavg': 22.6,
#    'tmin': 18.1,
#    'tmax': 27.7,
#    'prcp': 0.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-18',
#    'tavg': 21.1,
#    'tmin': 15.2,
#    'tmax': 26.9,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-19',
#    'tavg': 23.6,
#    'tmin': 15.2,
#    'tmax': 30.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-20',
#    'tavg': 22.8,
#    'tmin': 16.0,
#    'tmax': 29.5,
#    'prcp': 10.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-21',
#    'tavg': 25.4,
#    'tmin': 16.7,
#    'tmax': 34.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-22',
#    'tavg': 27.0,
#    'tmin': 15.1,
#    'tmax': 36.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-23',
#    'tavg': 26.6,
#    'tmin': 18.5,
#    'tmax': 36.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-24',
#    'tavg': 28.9,
#    'tmin': 23.3,
#    'tmax': 35.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-25',
#    'tavg': 29.4,
#    'tmin': 19.8,
#    'tmax': 36.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-26',
#    'tavg': 29.1,
#    'tmin': 15.3,
#    'tmax': 38.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-27',
#    'tavg': 25.6,
#    'tmin': 18.4,
#    'tmax': 37.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-28',
#    'tavg': 27.7,
#    'tmin': 20.0,
#    'tmax': 35.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-29',
#    'tavg': 28.6,
#    'tmin': 18.4,
#    'tmax': 36.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-30',
#    'tavg': 26.7,
#    'tmin': 18.4,
#    'tmax': 34.4,
#    'prcp': 0.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-01',
#    'tavg': 27.4,
#    'tmin': 20.4,
#    'tmax': 36.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-02',
#    'tavg': 26.5,
#    'tmin': 20.2,
#    'tmax': 32.6,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-03',
#    'tavg': 24.0,
#    'tmin': 17.6,
#    'tmax': 31.7,
#    'prcp': 0.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-04',
#    'tavg': 24.5,
#    'tmin': 16.7,
#    'tmax': 32.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-05',
#    'tavg': 25.3,
#    'tmin': 14.5,
#    'tmax': 35.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-06',
#    'tavg': 26.9,
#    'tmin': 17.7,
#    'tmax': 36.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-07',
#    'tavg': 29.0,
#    'tmin': 21.9,
#    'tmax': 35.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-08',
#    'tavg': 28.7,
#    'tmin': 24.0,
#    'tmax': 33.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-09',
#    'tavg': 26.9,
#    'tmin': 15.2,
#    'tmax': 35.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-10',
#    'tavg': 27.2,
#    'tmin': 18.6,
#    'tmax': 35.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-11',
#    'tavg': 25.6,
#    'tmin': 14.8,
#    'tmax': 36.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-12',
#    'tavg': 27.8,
#    'tmin': 19.5,
#    'tmax': 37.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-13',
#    'tavg': 28.7,
#    'tmin': 17.7,
#    'tmax': 39.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-14',
#    'tavg': 29.9,
#    'tmin': 17.8,
#    'tmax': 41.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-15',
#    'tavg': 31.2,
#    'tmin': 21.8,
#    'tmax': 41.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-16',
#    'tavg': 30.0,
#    'tmin': 26.7,
#    'tmax': 39.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-17',
#    'tavg': 29.3,
#    'tmin': 23.3,
#    'tmax': 36.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-18',
#    'tavg': 30.4,
#    'tmin': 23.5,
#    'tmax': 38.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-19',
#    'tavg': 31.0,
#    'tmin': 22.8,
#    'tmax': 39.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-20',
#    'tavg': 30.6,
#    'tmin': 21.2,
#    'tmax': 41.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-21',
#    'tavg': 32.6,
#    'tmin': 27.7,
#    'tmax': 38.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-22',
#    'tavg': 29.4,
#    'tmin': 21.5,
#    'tmax': 38.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-23',
#    'tavg': 29.6,
#    'tmin': 18.4,
#    'tmax': 38.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-24',
#    'tavg': 30.5,
#    'tmin': 19.0,
#    'tmax': 40.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-25',
#    'tavg': 30.9,
#    'tmin': 22.3,
#    'tmax': 41.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-26',
#    'tavg': 28.2,
#    'tmin': 22.4,
#    'tmax': 37.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-27',
#    'tavg': 25.4,
#    'tmin': 19.8,
#    'tmax': 30.7,
#    'prcp': 0.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-28',
#    'tavg': 25.6,
#    'tmin': 17.1,
#    'tmax': 33.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-29',
#    'tavg': 25.4,
#    'tmin': 14.3,
#    'tmax': 36.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-30',
#    'tavg': 27.0,
#    'tmin': 15.6,
#    'tmax': 38.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-31',
#    'tavg': 27.2,
#    'tmin': 14.2,
#    'tmax': 39.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-01',
#    'tavg': 28.5,
#    'tmin': 19.5,
#    'tmax': 36.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-02',
#    'tavg': 29.5,
#    'tmin': 23.3,
#    'tmax': 36.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-03',
#    'tavg': 29.3,
#    'tmin': 23.5,
#    'tmax': 35.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-04',
#    'tavg': 28.2,
#    'tmin': 18.9,
#    'tmax': 37.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-05',
#    'tavg': 28.3,
#    'tmin': 17.1,
#    'tmax': 40.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-06',
#    'tavg': 29.5,
#    'tmin': 18.2,
#    'tmax': 41.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-07',
#    'tavg': 31.5,
#    'tmin': 21.9,
#    'tmax': 41.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-08',
#    'tavg': 31.3,
#    'tmin': 23.4,
#    'tmax': 39.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-09',
#    'tavg': 29.2,
#    'tmin': 18.5,
#    'tmax': 37.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-10',
#    'tavg': 28.4,
#    'tmin': 22.3,
#    'tmax': 35.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-11',
#    'tavg': 28.2,
#    'tmin': 21.8,
#    'tmax': 34.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-12',
#    'tavg': 25.4,
#    'tmin': 20.7,
#    'tmax': 31.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-13',
#    'tavg': 26.0,
#    'tmin': 20.4,
#    'tmax': 31.4,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-14',
#    'tavg': 25.4,
#    'tmin': 19.0,
#    'tmax': 33.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-15',
#    'tavg': 26.5,
#    'tmin': 19.5,
#    'tmax': 35.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-16',
#    'tavg': 24.5,
#    'tmin': 17.6,
#    'tmax': 31.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-17',
#    'tavg': 26.8,
#    'tmin': 19.8,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-18',
#    'tavg': 25.9,
#    'tmin': 16.2,
#    'tmax': 34.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-19',
#    'tavg': 26.7,
#    'tmin': 18.3,
#    'tmax': 34.6,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-20',
#    'tavg': 25.8,
#    'tmin': 15.0,
#    'tmax': 36.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-21',
#    'tavg': 25.8,
#    'tmin': 14.4,
#    'tmax': 36.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-22',
#    'tavg': 26.7,
#    'tmin': 18.1,
#    'tmax': 34.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-23',
#    'tavg': 24.8,
#    'tmin': 14.1,
#    'tmax': 33.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-24',
#    'tavg': 24.3,
#    'tmin': 13.5,
#    'tmax': 35.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-25',
#    'tavg': 25.2,
#    'tmin': 14.5,
#    'tmax': 38.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-26',
#    'tavg': 28.3,
#    'tmin': 18.3,
#    'tmax': 39.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-27',
#    'tavg': 27.9,
#    'tmin': 20.8,
#    'tmax': 38.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-28',
#    'tavg': 27.6,
#    'tmin': 22.2,
#    'tmax': 33.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-29',
#    'tavg': 24.4,
#    'tmin': 14.0,
#    'tmax': 33.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-30',
#    'tavg': 25.0,
#    'tmin': 15.4,
#    'tmax': 34.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-31',
#    'tavg': 25.2,
#    'tmin': 18.4,
#    'tmax': 31.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-01',
#    'tavg': 23.5,
#    'tmin': 13.9,
#    'tmax': 32.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-02',
#    'tavg': 24.1,
#    'tmin': 18.9,
#    'tmax': 31.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-03',
#    'tavg': 22.4,
#    'tmin': 16.2,
#    'tmax': 29.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
# ...
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-08',
#    'tavg': 19.9,
#    'tmin': 14.1,
#    'tmax': None,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-09',
#    'tavg': 18.9,
#    'tmin': 12.3,
#    'tmax': None,
#    'prcp': 1.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-10',
#    'tavg': 23.0,
#    'tmin': 12.9,
#    'tmax': None,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-11',
#    'tavg': 25.4,
#    'tmin': 16.5,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-12',
#    'tavg': 26.9,
#    'tmin': 17.6,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-13',
#    'tavg': 25.3,
#    'tmin': 19.7,
#    'tmax': None,
#    'prcp': 2.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-14',
#    'tavg': 26.6,
#    'tmin': 18.9,
#    'tmax': 36.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-15',
#    'tavg': 30.2,
#    'tmin': 18.8,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-16',
#    'tavg': 30.1,
#    'tmin': 21.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-17',
#    'tavg': 27.3,
#    'tmin': 19.4,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-18',
#    'tavg': 26.9,
#    'tmin': 20.4,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-19',
#    'tavg': 25.1,
#    'tmin': 18.8,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-20',
#    'tavg': 27.1,
#    'tmin': 18.9,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-21',
#    'tavg': 28.6,
#    'tmin': 17.9,
#    'tmax': 36.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-22',
#    'tavg': 31.7,
#    'tmin': 19.5,
#    'tmax': 39.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-23',
#    'tavg': 26.4,
#    'tmin': 21.5,
#    'tmax': 33.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-24',
#    'tavg': 25.5,
#    'tmin': 18.9,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-25',
#    'tavg': 24.7,
#    'tmin': 18.7,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-26',
#    'tavg': 25.4,
#    'tmin': 16.7,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-27',
#    'tavg': 26.3,
#    'tmin': 15.4,
#    'tmax': 35.3,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-28',
#    'tavg': 28.4,
#    'tmin': 18.7,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-29',
#    'tavg': 29.7,
#    'tmin': 18.1,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-30',
#    'tavg': 29.6,
#    'tmin': 19.1,
#    'tmax': 37.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-31',
#    'tavg': 28.2,
#    'tmin': 19.9,
#    'tmax': 34.5,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-01',
#    'tavg': 29.4,
#    'tmin': 24.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-02',
#    'tavg': 28.9,
#    'tmin': 26.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-03',
#    'tavg': 30.4,
#    'tmin': 16.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-04',
#    'tavg': 30.7,
#    'tmin': 22.0,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-05',
#    'tavg': 25.9,
#    'tmin': 22.5,
#    'tmax': None,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-06',
#    'tavg': 27.9,
#    'tmin': 18.4,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-07',
#    'tavg': 28.6,
#    'tmin': 20.6,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-08',
#    'tavg': 30.7,
#    'tmin': 20.6,
#    'tmax': 39.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-09',
#    'tavg': 28.2,
#    'tmin': 21.9,
#    'tmax': 35.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-10',
#    'tavg': 27.6,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-11',
#    'tavg': 29.5,
#    'tmin': 16.3,
#    'tmax': 35.4,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-12',
#    'tavg': 30.7,
#    'tmin': 22.1,
#    'tmax': 35.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-13',
#    'tavg': 29.7,
#    'tmin': 24.5,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-14',
#    'tavg': 24.2,
#    'tmin': 17.9,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-15',
#    'tavg': 21.2,
#    'tmin': 17.6,
#    'tmax': None,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-16',
#    'tavg': 23.6,
#    'tmin': 13.1,
#    'tmax': None,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-17',
#    'tavg': 25.3,
#    'tmin': 15.9,
#    'tmax': 33.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-18',
#    'tavg': 25.9,
#    'tmin': 16.2,
#    'tmax': 33.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-19',
#    'tavg': 24.9,
#    'tmin': 19.8,
#    'tmax': 34.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-20',
#    'tavg': 26.6,
#    'tmin': 16.7,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-21',
#    'tavg': 24.3,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-22',
#    'tavg': 25.7,
#    'tmin': 13.7,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-23',
#    'tavg': 26.9,
#    'tmin': 16.0,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-24',
#    'tavg': 28.2,
#    'tmin': 22.6,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-25',
#    'tavg': 30.2,
#    'tmin': 18.8,
#    'tmax': 34.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-26',
#    'tavg': 24.8,
#    'tmin': 20.5,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-27',
#    'tavg': 22.3,
#    'tmin': 20.3,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-28',
#    'tavg': 23.2,
#    'tmin': 11.7,
#    'tmax': 34.2,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-29',
#    'tavg': 24.9,
#    'tmin': 12.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-30',
#    'tavg': 27.5,
#    'tmin': 14.0,
#    'tmax': 36.3,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-31',
#    'tavg': 24.6,
#    'tmin': 19.9,
#    'tmax': None,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-01',
#    'tavg': 23.2,
#    'tmin': 16.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-02',
#    'tavg': 20.6,
#    'tmin': None,
#    'tmax': 29.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-03',
#    'tavg': 20.4,
#    'tmin': 10.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-04',
#    'tavg': 20.8,
#    'tmin': 9.6,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-05',
#    'tavg': 22.0,
#    'tmin': 11.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-06',
#    'tavg': 24.8,
#    'tmin': 13.1,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-07',
#    'tavg': 21.2,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-08',
#    'tavg': 22.0,
#    'tmin': 10.9,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-09',
#    'tavg': 22.7,
#    'tmin': 11.7,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-10',
#    'tavg': 23.2,
#    'tmin': 11.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-11',
#    'tavg': 22.9,
#    'tmin': 11.6,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-12',
#    'tavg': 25.0,
#    'tmin': 12.5,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-13',
#    'tavg': 23.3,
#    'tmin': 16.5,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-14',
#    'tavg': 22.4,
#    'tmin': 22.1,
#    'tmax': 31.6,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-15',
#    'tavg': 22.8,
#    'tmin': 11.6,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-16',
#    'tavg': 22.0,
#    'tmin': 14.7,
#    'tmax': 25.3,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-17',
#    'tavg': 18.2,
#    'tmin': 13.2,
#    'tmax': 25.7,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-18',
#    'tavg': 16.9,
#    'tmin': None,
#    'tmax': 27.8,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-19',
#    'tavg': 17.7,
#    'tmin': 6.9,
#    'tmax': 29.5,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-20',
#    'tavg': 19.3,
#    'tmin': 7.7,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-21',
#    'tavg': 20.4,
#    'tmin': 8.6,
#    'tmax': 31.4,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-22',
#    'tavg': 14.5,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-23',
#    'tavg': 13.0,
#    'tmin': 11.8,
#    'tmax': 22.8,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-24',
#    'tavg': 13.2,
#    'tmin': 3.5,
#    'tmax': 24.3,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-25',
#    'tavg': 14.6,
#    'tmin': 5.6,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-26',
#    'tavg': 16.4,
#    'tmin': 6.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   ...]}

# %%
detroit
# Out:
# {'meta': {'generated': '2023-07-07 01:47:15', 'stations': ['51644']},
#  'data': [{'date': '2011-01-01',
#    'tavg': -10.0,
#    'tmin': -14.3,
#    'tmax': -4.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-02',
#    'tavg': -11.0,
#    'tmin': -15.8,
#    'tmax': -6.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-03',
#    'tavg': -12.3,
#    'tmin': -17.8,
#    'tmax': -7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-04',
#    'tavg': -12.9,
#    'tmin': -17.0,
#    'tmax': -8.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-05',
#    'tavg': -13.8,
#    'tmin': -18.2,
#    'tmax': -8.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-06',
#    'tavg': -14.0,
#    'tmin': -19.2,
#    'tmax': -8.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-07',
#    'tavg': -14.5,
#    'tmin': -20.0,
#    'tmax': -8.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-08',
#    'tavg': -14.1,
#    'tmin': -19.8,
#    'tmax': -7.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-09',
#    'tavg': -14.2,
#    'tmin': -20.1,
#    'tmax': -6.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-10',
#    'tavg': -14.5,
#    'tmin': -20.1,
#    'tmax': -7.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-11',
#    'tavg': -14.7,
#    'tmin': -20.1,
#    'tmax': -7.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-12',
#    'tavg': -14.2,
#    'tmin': -20.5,
#    'tmax': -6.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-13',
#    'tavg': -13.7,
#    'tmin': -19.6,
#    'tmax': -5.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-14',
#    'tavg': -12.2,
#    'tmin': -18.7,
#    'tmax': -5.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-15',
#    'tavg': -13.1,
#    'tmin': -19.0,
#    'tmax': -5.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-16',
#    'tavg': -11.9,
#    'tmin': -17.1,
#    'tmax': -7.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-17',
#    'tavg': -13.7,
#    'tmin': -19.5,
#    'tmax': -7.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-18',
#    'tavg': -12.6,
#    'tmin': -18.5,
#    'tmax': -6.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-19',
#    'tavg': -10.5,
#    'tmin': -14.3,
#    'tmax': -5.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-20',
#    'tavg': -12.0,
#    'tmin': -17.9,
#    'tmax': -4.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-21',
#    'tavg': -11.6,
#    'tmin': -17.9,
#    'tmax': -3.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-22',
#    'tavg': -11.3,
#    'tmin': -16.9,
#    'tmax': -4.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-23',
#    'tavg': -8.6,
#    'tmin': -14.3,
#    'tmax': -1.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-24',
#    'tavg': -9.7,
#    'tmin': -16.6,
#    'tmax': -2.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-25',
#    'tavg': -9.3,
#    'tmin': -16.1,
#    'tmax': -2.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-26',
#    'tavg': -10.1,
#    'tmin': -16.7,
#    'tmax': -3.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-27',
#    'tavg': -10.3,
#    'tmin': -17.0,
#    'tmax': -3.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-28',
#    'tavg': -11.7,
#    'tmin': -18.4,
#    'tmax': -4.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-29',
#    'tavg': -11.8,
#    'tmin': -18.3,
#    'tmax': -4.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-30',
#    'tavg': -11.6,
#    'tmin': -17.7,
#    'tmax': -4.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-31',
#    'tavg': -10.3,
#    'tmin': -16.9,
#    'tmax': -2.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-01',
#    'tavg': -8.3,
#    'tmin': -15.4,
#    'tmax': 0.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-02',
#    'tavg': -7.5,
#    'tmin': -14.0,
#    'tmax': 0.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-03',
#    'tavg': -6.5,
#    'tmin': -12.2,
#    'tmax': -0.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-04',
#    'tavg': -3.0,
#    'tmin': -9.2,
#    'tmax': 4.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-05',
#    'tavg': -2.0,
#    'tmin': -6.7,
#    'tmax': 5.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-06',
#    'tavg': -0.7,
#    'tmin': -6.2,
#    'tmax': 6.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-07',
#    'tavg': 0.4,
#    'tmin': -2.8,
#    'tmax': 4.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-08',
#    'tavg': 1.4,
#    'tmin': -2.5,
#    'tmax': 6.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-09',
#    'tavg': 0.0,
#    'tmin': -5.3,
#    'tmax': 6.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-10',
#    'tavg': 0.2,
#    'tmin': -2.4,
#    'tmax': 4.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-11',
#    'tavg': 0.5,
#    'tmin': -4.8,
#    'tmax': 6.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-12',
#    'tavg': 0.4,
#    'tmin': -5.4,
#    'tmax': 6.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-13',
#    'tavg': 0.6,
#    'tmin': -3.2,
#    'tmax': 5.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-14',
#    'tavg': 1.3,
#    'tmin': -3.6,
#    'tmax': 5.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-15',
#    'tavg': 0.8,
#    'tmin': -6.0,
#    'tmax': 8.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-16',
#    'tavg': 1.1,
#    'tmin': -5.5,
#    'tmax': 9.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-17',
#    'tavg': 1.7,
#    'tmin': -4.4,
#    'tmax': 8.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-18',
#    'tavg': 1.7,
#    'tmin': -4.4,
#    'tmax': 9.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-19',
#    'tavg': 1.6,
#    'tmin': -4.9,
#    'tmax': 9.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-20',
#    'tavg': 1.9,
#    'tmin': -3.8,
#    'tmax': 7.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-21',
#    'tavg': 2.4,
#    'tmin': -4.8,
#    'tmax': 10.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-22',
#    'tavg': 3.5,
#    'tmin': -3.4,
#    'tmax': 11.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-23',
#    'tavg': 4.7,
#    'tmin': -2.5,
#    'tmax': 12.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-24',
#    'tavg': 3.8,
#    'tmin': -1.9,
#    'tmax': 11.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-25',
#    'tavg': 3.5,
#    'tmin': -1.4,
#    'tmax': 8.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-26',
#    'tavg': 0.5,
#    'tmin': -3.4,
#    'tmax': 4.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-27',
#    'tavg': 0.4,
#    'tmin': -1.4,
#    'tmax': 2.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-28',
#    'tavg': -0.8,
#    'tmin': -4.8,
#    'tmax': 3.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-01',
#    'tavg': -0.9,
#    'tmin': -5.5,
#    'tmax': 3.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-02',
#    'tavg': 0.7,
#    'tmin': -5.3,
#    'tmax': 5.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-03',
#    'tavg': 1.4,
#    'tmin': -1.9,
#    'tmax': 6.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-04',
#    'tavg': 0.5,
#    'tmin': -4.7,
#    'tmax': 6.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-05',
#    'tavg': 1.8,
#    'tmin': -3.5,
#    'tmax': 8.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-06',
#    'tavg': 2.8,
#    'tmin': -2.6,
#    'tmax': 9.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-07',
#    'tavg': 2.9,
#    'tmin': -3.2,
#    'tmax': 9.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-08',
#    'tavg': 3.7,
#    'tmin': -1.5,
#    'tmax': 10.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-09',
#    'tavg': 4.6,
#    'tmin': -2.3,
#    'tmax': 11.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-10',
#    'tavg': 5.0,
#    'tmin': -2.0,
#    'tmax': 12.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-11',
#    'tavg': 6.4,
#    'tmin': -1.2,
#    'tmax': 13.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-12',
#    'tavg': 4.3,
#    'tmin': -0.4,
#    'tmax': 11.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-13',
#    'tavg': 2.7,
#    'tmin': -1.5,
#    'tmax': 6.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-14',
#    'tavg': 1.6,
#    'tmin': -2.9,
#    'tmax': 6.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-15',
#    'tavg': 2.4,
#    'tmin': -2.7,
#    'tmax': 8.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-16',
#    'tavg': 2.5,
#    'tmin': -1.4,
#    'tmax': 7.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-17',
#    'tavg': 0.3,
#    'tmin': -7.0,
#    'tmax': 5.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-18',
#    'tavg': 1.6,
#    'tmin': -4.4,
#    'tmax': 8.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-19',
#    'tavg': 4.1,
#    'tmin': -2.7,
#    'tmax': 10.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-20',
#    'tavg': 2.0,
#    'tmin': 0.4,
#    'tmax': 8.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-21',
#    'tavg': -0.5,
#    'tmin': -3.4,
#    'tmax': 3.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-22',
#    'tavg': -0.3,
#    'tmin': -5.4,
#    'tmax': 4.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-23',
#    'tavg': 0.8,
#    'tmin': -5.1,
#    'tmax': 6.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-24',
#    'tavg': 2.2,
#    'tmin': -4.5,
#    'tmax': 9.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-25',
#    'tavg': 3.6,
#    'tmin': -3.6,
#    'tmax': 11.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-26',
#    'tavg': 5.9,
#    'tmin': -1.6,
#    'tmax': 14.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-27',
#    'tavg': 9.4,
#    'tmin': 2.5,
#    'tmax': 17.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-28',
#    'tavg': 10.4,
#    'tmin': 3.5,
#    'tmax': 18.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-29',
#    'tavg': 11.2,
#    'tmin': 3.5,
#    'tmax': 18.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-30',
#    'tavg': 11.3,
#    'tmin': 3.9,
#    'tmax': 19.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-31',
#    'tavg': 11.5,
#    'tmin': 2.4,
#    'tmax': 20.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-01',
#    'tavg': 12.6,
#    'tmin': 5.6,
#    'tmax': 19.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-02',
#    'tavg': 11.5,
#    'tmin': 4.3,
#    'tmax': 19.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-03',
#    'tavg': 13.1,
#    'tmin': 5.9,
#    'tmax': 19.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-04',
#    'tavg': 9.5,
#    'tmin': 6.9,
#    'tmax': 17.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-05',
#    'tavg': 3.3,
#    'tmin': -0.2,
#    'tmax': 7.2,
#    'prcp': 2.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-06',
#    'tavg': 5.1,
#    'tmin': -1.3,
#    'tmax': 11.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-07',
#    'tavg': 6.6,
#    'tmin': -1.0,
#    'tmax': 14.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-08',
#    'tavg': 9.6,
#    'tmin': 1.9,
#    'tmax': 17.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-09',
#    'tavg': 11.3,
#    'tmin': 2.9,
#    'tmax': 20.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-10',
#    'tavg': 12.9,
#    'tmin': 5.1,
#    'tmax': 20.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-11',
#    'tavg': 13.9,
#    'tmin': 7.3,
#    'tmax': 21.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-12',
#    'tavg': 18.2,
#    'tmin': 10.5,
#    'tmax': 24.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-13',
#    'tavg': 17.9,
#    'tmin': 11.9,
#    'tmax': 25.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-14',
#    'tavg': 19.2,
#    'tmin': 10.6,
#    'tmax': 26.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-15',
#    'tavg': 19.5,
#    'tmin': 9.7,
#    'tmax': 27.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-16',
#    'tavg': 19.0,
#    'tmin': 10.1,
#    'tmax': 28.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-17',
#    'tavg': 22.0,
#    'tmin': 15.0,
#    'tmax': 26.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-18',
#    'tavg': 20.6,
#    'tmin': 12.9,
#    'tmax': 27.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-19',
#    'tavg': 20.1,
#    'tmin': 14.5,
#    'tmax': 26.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-20',
#    'tavg': 21.6,
#    'tmin': 16.9,
#    'tmax': 26.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-21',
#    'tavg': 20.3,
#    'tmin': 16.1,
#    'tmax': 24.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-22',
#    'tavg': 20.0,
#    'tmin': 14.5,
#    'tmax': 25.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-23',
#    'tavg': 19.1,
#    'tmin': 9.9,
#    'tmax': 27.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-24',
#    'tavg': 20.9,
#    'tmin': 11.8,
#    'tmax': 29.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-25',
#    'tavg': 21.6,
#    'tmin': 11.7,
#    'tmax': 31.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-26',
#    'tavg': 23.1,
#    'tmin': 12.7,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-27',
#    'tavg': 23.7,
#    'tmin': 14.6,
#    'tmax': 33.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-28',
#    'tavg': 24.7,
#    'tmin': 14.5,
#    'tmax': 31.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-29',
#    'tavg': 21.3,
#    'tmin': 18.3,
#    'tmax': 28.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-30',
#    'tavg': 17.4,
#    'tmin': 14.8,
#    'tmax': 22.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-01',
#    'tavg': 17.4,
#    'tmin': 11.1,
#    'tmax': 24.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-02',
#    'tavg': 17.4,
#    'tmin': 6.8,
#    'tmax': 24.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-03',
#    'tavg': 18.4,
#    'tmin': 8.6,
#    'tmax': 28.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-04',
#    'tavg': 21.8,
#    'tmin': 12.1,
#    'tmax': 31.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-05',
#    'tavg': 24.3,
#    'tmin': 13.2,
#    'tmax': 33.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-06',
#    'tavg': 23.6,
#    'tmin': 17.0,
#    'tmax': 31.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-07',
#    'tavg': 22.2,
#    'tmin': 17.1,
#    'tmax': 28.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-08',
#    'tavg': 18.8,
#    'tmin': 16.4,
#    'tmax': 24.0,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-09',
#    'tavg': 15.2,
#    'tmin': 10.4,
#    'tmax': 21.5,
#    'prcp': 10.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-10',
#    'tavg': 15.0,
#    'tmin': 12.7,
#    'tmax': 19.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-11',
#    'tavg': 15.9,
#    'tmin': 9.0,
#    'tmax': 20.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-12',
#    'tavg': 16.6,
#    'tmin': 13.4,
#    'tmax': 21.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-13',
#    'tavg': 17.3,
#    'tmin': 9.0,
#    'tmax': 24.6,
#    'prcp': 1.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-14',
#    'tavg': 18.8,
#    'tmin': 10.0,
#    'tmax': 27.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-15',
#    'tavg': 21.2,
#    'tmin': 11.5,
#    'tmax': 30.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-16',
#    'tavg': 23.6,
#    'tmin': 14.3,
#    'tmax': 33.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-17',
#    'tavg': 23.3,
#    'tmin': 14.9,
#    'tmax': 31.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-18',
#    'tavg': 24.0,
#    'tmin': 18.9,
#    'tmax': 29.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-19',
#    'tavg': 19.1,
#    'tmin': 15.3,
#    'tmax': 25.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-20',
#    'tavg': 13.6,
#    'tmin': 12.3,
#    'tmax': 16.1,
#    'prcp': 11.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-21',
#    'tavg': 15.4,
#    'tmin': 10.4,
#    'tmax': 20.8,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-22',
#    'tavg': 17.1,
#    'tmin': 10.9,
#    'tmax': 24.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-23',
#    'tavg': 18.2,
#    'tmin': 8.5,
#    'tmax': 26.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-24',
#    'tavg': 15.6,
#    'tmin': 9.7,
#    'tmax': 25.9,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-25',
#    'tavg': 18.5,
#    'tmin': 10.1,
#    'tmax': 27.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-26',
#    'tavg': 20.4,
#    'tmin': 13.6,
#    'tmax': 27.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-27',
#    'tavg': 23.3,
#    'tmin': 14.9,
#    'tmax': 30.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-28',
#    'tavg': 22.4,
#    'tmin': 15.1,
#    'tmax': 27.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-29',
#    'tavg': 21.7,
#    'tmin': 16.6,
#    'tmax': 27.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-30',
#    'tavg': 20.7,
#    'tmin': 11.9,
#    'tmax': 28.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-31',
#    'tavg': 23.8,
#    'tmin': 16.5,
#    'tmax': 29.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-01',
#    'tavg': 21.6,
#    'tmin': 16.5,
#    'tmax': 28.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-02',
#    'tavg': 21.7,
#    'tmin': 19.0,
#    'tmax': 26.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-03',
#    'tavg': 22.2,
#    'tmin': 14.2,
#    'tmax': 28.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-04',
#    'tavg': 22.1,
#    'tmin': 12.6,
#    'tmax': 31.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-05',
#    'tavg': 23.8,
#    'tmin': 15.4,
#    'tmax': 33.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-06',
#    'tavg': 26.3,
#    'tmin': 19.0,
#    'tmax': 31.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-07',
#    'tavg': 22.7,
#    'tmin': 16.5,
#    'tmax': 29.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-08',
#    'tavg': 23.1,
#    'tmin': 12.4,
#    'tmax': 31.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-09',
#    'tavg': 23.6,
#    'tmin': 17.9,
#    'tmax': 29.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-10',
#    'tavg': 21.1,
#    'tmin': 14.3,
#    'tmax': 30.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-11',
#    'tavg': 23.4,
#    'tmin': 13.8,
#    'tmax': 32.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-12',
#    'tavg': 25.8,
#    'tmin': 17.7,
#    'tmax': 33.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-13',
#    'tavg': 27.3,
#    'tmin': 18.3,
#    'tmax': 35.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-14',
#    'tavg': 26.8,
#    'tmin': 22.1,
#    'tmax': 32.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-15',
#    'tavg': 25.9,
#    'tmin': 18.9,
#    'tmax': 31.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-16',
#    'tavg': 23.5,
#    'tmin': 18.0,
#    'tmax': 31.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-17',
#    'tavg': 21.3,
#    'tmin': 14.2,
#    'tmax': 27.8,
#    'prcp': 0.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-18',
#    'tavg': 18.8,
#    'tmin': 15.1,
#    'tmax': 25.8,
#    'prcp': 16.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-19',
#    'tavg': 18.0,
#    'tmin': 13.1,
#    'tmax': 25.6,
#    'prcp': 2.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-20',
#    'tavg': 20.0,
#    'tmin': 12.3,
#    'tmax': 27.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-21',
#    'tavg': 19.7,
#    'tmin': 14.0,
#    'tmax': 29.4,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-22',
#    'tavg': 22.4,
#    'tmin': 14.8,
#    'tmax': 30.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-23',
#    'tavg': 25.6,
#    'tmin': 18.5,
#    'tmax': 31.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-24',
#    'tavg': 24.2,
#    'tmin': 15.9,
#    'tmax': 32.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-25',
#    'tavg': 24.4,
#    'tmin': 15.7,
#    'tmax': 32.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-26',
#    'tavg': 26.1,
#    'tmin': 17.4,
#    'tmax': 34.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-27',
#    'tavg': 28.1,
#    'tmin': 21.7,
#    'tmax': 33.1,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-28',
#    'tavg': 24.9,
#    'tmin': 18.8,
#    'tmax': 31.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-29',
#    'tavg': 24.3,
#    'tmin': 18.9,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-30',
#    'tavg': 22.4,
#    'tmin': 13.4,
#    'tmax': 30.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-01',
#    'tavg': 20.7,
#    'tmin': 15.0,
#    'tmax': 28.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-02',
#    'tavg': 22.5,
#    'tmin': 14.6,
#    'tmax': 29.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-03',
#    'tavg': 24.3,
#    'tmin': 17.6,
#    'tmax': 29.4,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-04',
#    'tavg': 22.5,
#    'tmin': 12.3,
#    'tmax': 29.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-05',
#    'tavg': 22.8,
#    'tmin': 14.5,
#    'tmax': 32.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-06',
#    'tavg': 26.4,
#    'tmin': 15.4,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-07',
#    'tavg': 24.7,
#    'tmin': 17.3,
#    'tmax': 32.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-08',
#    'tavg': 27.5,
#    'tmin': 17.7,
#    'tmax': 33.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-09',
#    'tavg': 24.2,
#    'tmin': 16.3,
#    'tmax': 32.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-10',
#    'tavg': 22.6,
#    'tmin': 18.0,
#    'tmax': 28.1,
#    'prcp': 1.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-11',
#    'tavg': 23.7,
#    'tmin': 17.2,
#    'tmax': 30.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-12',
#    'tavg': 24.4,
#    'tmin': 16.1,
#    'tmax': 33.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-13',
#    'tavg': 26.1,
#    'tmin': 17.1,
#    'tmax': 35.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-14',
#    'tavg': 29.5,
#    'tmin': 19.1,
#    'tmax': 37.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-15',
#    'tavg': 28.3,
#    'tmin': 20.3,
#    'tmax': 35.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-16',
#    'tavg': 28.3,
#    'tmin': 23.3,
#    'tmax': 32.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-17',
#    'tavg': 26.4,
#    'tmin': 16.7,
#    'tmax': 33.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-18',
#    'tavg': 26.5,
#    'tmin': 17.7,
#    'tmax': 35.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-19',
#    'tavg': 26.4,
#    'tmin': 18.3,
#    'tmax': 36.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-20',
#    'tavg': 27.3,
#    'tmin': 21.8,
#    'tmax': 30.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-21',
#    'tavg': 26.3,
#    'tmin': 16.1,
#    'tmax': 34.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-22',
#    'tavg': 28.7,
#    'tmin': 19.2,
#    'tmax': 34.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-23',
#    'tavg': 27.3,
#    'tmin': 19.8,
#    'tmax': 33.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-24',
#    'tavg': 27.4,
#    'tmin': 19.9,
#    'tmax': 35.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-25',
#    'tavg': 27.7,
#    'tmin': 19.9,
#    'tmax': 36.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-26',
#    'tavg': 26.1,
#    'tmin': 20.1,
#    'tmax': 33.7,
#    'prcp': 6.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-27',
#    'tavg': 22.4,
#    'tmin': 14.8,
#    'tmax': 29.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-28',
#    'tavg': 23.2,
#    'tmin': 16.5,
#    'tmax': 29.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-29',
#    'tavg': 23.6,
#    'tmin': 16.4,
#    'tmax': 31.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-30',
#    'tavg': 24.0,
#    'tmin': 16.1,
#    'tmax': 33.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-31',
#    'tavg': 25.5,
#    'tmin': 18.9,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-01',
#    'tavg': 26.5,
#    'tmin': 23.6,
#    'tmax': 28.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-02',
#    'tavg': 25.2,
#    'tmin': 16.4,
#    'tmax': 35.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-03',
#    'tavg': 25.9,
#    'tmin': 16.5,
#    'tmax': 32.7,
#    'prcp': 0.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-04',
#    'tavg': 25.1,
#    'tmin': 15.6,
#    'tmax': 34.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-05',
#    'tavg': 26.5,
#    'tmin': 17.1,
#    'tmax': 36.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-06',
#    'tavg': 28.6,
#    'tmin': 18.3,
#    'tmax': 36.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-07',
#    'tavg': 27.6,
#    'tmin': 18.1,
#    'tmax': 37.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-08',
#    'tavg': 29.3,
#    'tmin': 22.1,
#    'tmax': 36.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-09',
#    'tavg': 28.6,
#    'tmin': 23.6,
#    'tmax': 34.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-10',
#    'tavg': 26.3,
#    'tmin': 19.6,
#    'tmax': 31.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-11',
#    'tavg': 20.3,
#    'tmin': 17.2,
#    'tmax': 29.5,
#    'prcp': 4.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-12',
#    'tavg': 18.7,
#    'tmin': 12.5,
#    'tmax': 26.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-13',
#    'tavg': 21.2,
#    'tmin': 13.0,
#    'tmax': 28.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-14',
#    'tavg': 22.1,
#    'tmin': 13.6,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-15',
#    'tavg': 22.8,
#    'tmin': 14.2,
#    'tmax': 32.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-16',
#    'tavg': 22.8,
#    'tmin': 18.5,
#    'tmax': 30.4,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-17',
#    'tavg': 20.3,
#    'tmin': 14.9,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-18',
#    'tavg': 22.1,
#    'tmin': 14.7,
#    'tmax': 29.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-19',
#    'tavg': 22.9,
#    'tmin': 14.5,
#    'tmax': 30.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-20',
#    'tavg': 23.7,
#    'tmin': 15.7,
#    'tmax': 32.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-21',
#    'tavg': 26.4,
#    'tmin': 16.9,
#    'tmax': 32.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-22',
#    'tavg': 28.1,
#    'tmin': 20.8,
#    'tmax': 34.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-23',
#    'tavg': 23.9,
#    'tmin': 14.6,
#    'tmax': 32.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-24',
#    'tavg': 24.0,
#    'tmin': 16.0,
#    'tmax': 32.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-25',
#    'tavg': 24.8,
#    'tmin': 17.0,
#    'tmax': 33.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-26',
#    'tavg': 25.2,
#    'tmin': 17.5,
#    'tmax': 34.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-27',
#    'tavg': 26.6,
#    'tmin': 20.0,
#    'tmax': 31.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-28',
#    'tavg': 25.6,
#    'tmin': 20.4,
#    'tmax': 29.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-29',
#    'tavg': 20.2,
#    'tmin': 16.8,
#    'tmax': 27.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-30',
#    'tavg': 19.2,
#    'tmin': 16.0,
#    'tmax': 22.8,
#    'prcp': 3.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-31',
#    'tavg': 19.0,
#    'tmin': 15.6,
#    'tmax': 21.3,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-01',
#    'tavg': 18.8,
#    'tmin': 14.8,
#    'tmax': 25.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-02',
#    'tavg': 18.9,
#    'tmin': 13.2,
#    'tmax': 26.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-03',
#    'tavg': 22.3,
#    'tmin': 16.5,
#    'tmax': 28.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
# ...
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-08',
#    'tavg': 17.9,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-09',
#    'tavg': 16.8,
#    'tmin': 11.8,
#    'tmax': None,
#    'prcp': 6.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-10',
#    'tavg': 20.9,
#    'tmin': 11.2,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-11',
#    'tavg': 22.1,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-12',
#    'tavg': 23.9,
#    'tmin': 14.8,
#    'tmax': None,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-13',
#    'tavg': 24.1,
#    'tmin': 15.4,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-14',
#    'tavg': 26.9,
#    'tmin': 15.8,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-15',
#    'tavg': 23.9,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-16',
#    'tavg': 25.8,
#    'tmin': 16.4,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-17',
#    'tavg': 26.2,
#    'tmin': 15.1,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-18',
#    'tavg': 27.0,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-19',
#    'tavg': 26.2,
#    'tmin': 19.3,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-20',
#    'tavg': 24.1,
#    'tmin': 18.5,
#    'tmax': None,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-21',
#    'tavg': 25.6,
#    'tmin': 18.8,
#    'tmax': None,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-22',
#    'tavg': 18.5,
#    'tmin': None,
#    'tmax': 25.8,
#    'prcp': 6.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-23',
#    'tavg': 24.5,
#    'tmin': 14.2,
#    'tmax': None,
#    'prcp': 5.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-24',
#    'tavg': 24.4,
#    'tmin': 16.5,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-25',
#    'tavg': 23.6,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-26',
#    'tavg': 21.8,
#    'tmin': 15.3,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-27',
#    'tavg': 23.9,
#    'tmin': 15.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-28',
#    'tavg': 26.8,
#    'tmin': 17.2,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-29',
#    'tavg': 27.5,
#    'tmin': 18.0,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-30',
#    'tavg': 28.3,
#    'tmin': 18.2,
#    'tmax': 35.5,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-31',
#    'tavg': 27.2,
#    'tmin': None,
#    'tmax': 34.5,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-01',
#    'tavg': 28.1,
#    'tmin': 18.5,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-02',
#    'tavg': 29.9,
#    'tmin': 21.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-03',
#    'tavg': 30.6,
#    'tmin': 24.5,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-04',
#    'tavg': 28.3,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-05',
#    'tavg': 24.9,
#    'tmin': 19.6,
#    'tmax': None,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-06',
#    'tavg': 26.6,
#    'tmin': 19.4,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-07',
#    'tavg': 26.6,
#    'tmin': 19.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-08',
#    'tavg': 23.4,
#    'tmin': None,
#    'tmax': 30.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-09',
#    'tavg': 23.6,
#    'tmin': 16.5,
#    'tmax': 32.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-10',
#    'tavg': 23.6,
#    'tmin': 17.5,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-11',
#    'tavg': 26.2,
#    'tmin': 17.9,
#    'tmax': 32.3,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-12',
#    'tavg': 26.9,
#    'tmin': 19.8,
#    'tmax': 31.5,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-13',
#    'tavg': 24.2,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-14',
#    'tavg': 21.1,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-15',
#    'tavg': 20.9,
#    'tmin': 15.1,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-16',
#    'tavg': 21.4,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 2.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-17',
#    'tavg': 19.3,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 2.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-18',
#    'tavg': 20.8,
#    'tmin': 12.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-19',
#    'tavg': 23.1,
#    'tmin': 14.6,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-20',
#    'tavg': 23.3,
#    'tmin': 17.2,
#    'tmax': None,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-21',
#    'tavg': 24.6,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-22',
#    'tavg': 26.2,
#    'tmin': 20.8,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-23',
#    'tavg': 26.1,
#    'tmin': 20.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-24',
#    'tavg': 26.7,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-25',
#    'tavg': 23.4,
#    'tmin': 19.7,
#    'tmax': 29.9,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-26',
#    'tavg': 23.4,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-27',
#    'tavg': 22.5,
#    'tmin': 14.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-28',
#    'tavg': 24.3,
#    'tmin': 14.2,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-29',
#    'tavg': 24.1,
#    'tmin': 16.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-30',
#    'tavg': 23.1,
#    'tmin': 18.4,
#    'tmax': 30.4,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-31',
#    'tavg': 25.2,
#    'tmin': 14.8,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-01',
#    'tavg': 21.7,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-02',
#    'tavg': 21.9,
#    'tmin': 15.1,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-03',
#    'tavg': 20.8,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-04',
#    'tavg': 19.8,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-05',
#    'tavg': 18.9,
#    'tmin': 12.5,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-06',
#    'tavg': 20.5,
#    'tmin': 12.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-07',
#    'tavg': 21.9,
#    'tmin': 13.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-08',
#    'tavg': 20.4,
#    'tmin': 13.0,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-09',
#    'tavg': 20.9,
#    'tmin': 12.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-10',
#    'tavg': 22.4,
#    'tmin': 13.0,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-11',
#    'tavg': 22.4,
#    'tmin': 13.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-12',
#    'tavg': 24.4,
#    'tmin': 14.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-13',
#    'tavg': 22.9,
#    'tmin': 15.3,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-14',
#    'tavg': 19.7,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 1.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-15',
#    'tavg': 17.2,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-16',
#    'tavg': 13.2,
#    'tmin': None,
#    'tmax': 17.3,
#    'prcp': 8.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-17',
#    'tavg': 15.3,
#    'tmin': 7.7,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-18',
#    'tavg': 16.1,
#    'tmin': 7.1,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-19',
#    'tavg': 17.4,
#    'tmin': 10.0,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-20',
#    'tavg': 19.1,
#    'tmin': 10.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-21',
#    'tavg': 21.6,
#    'tmin': 10.7,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-22',
#    'tavg': 15.9,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-23',
#    'tavg': 13.1,
#    'tmin': 7.9,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-24',
#    'tavg': 13.7,
#    'tmin': 8.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-25',
#    'tavg': 14.8,
#    'tmin': 8.0,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-26',
#    'tavg': 16.5,
#    'tmin': 8.2,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   ...]}

# %%
columbus
# Out:
# {'meta': {'generated': '2023-07-07 01:47:17', 'stations': []}, 'data': []}

# %%
philly
# Out:
# {'meta': {'generated': '2023-07-07 01:47:17', 'stations': []}, 'data': []}

# %%
newark
# Out:
# {'meta': {'generated': '2023-07-07 01:47:18', 'stations': ['38628', '38745']},
#  'data': []}

# %%
houston
# Out:
# {'meta': {'generated': '2023-07-07 01:47:19', 'stations': ['42220']},
#  'data': [{'date': '2011-01-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
# ...
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-27',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-28',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-29',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-30',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-31',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-01',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-02',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-03',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-04',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-05',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-06',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-07',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-08',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-09',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-10',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-11',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-12',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-13',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-14',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-15',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-16',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-17',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-18',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-19',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-20',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-21',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-22',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-23',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-24',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-25',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-26',
#    'tavg': None,
#    'tmin': None,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   ...]}

# %%
indianapolis
# Out:
# {'meta': {'generated': '2023-07-07 01:47:20', 'stations': ['51855']},
#  'data': []}

# %%
milwaukee
# Out:
# {'meta': {'generated': '2023-07-07 01:47:22', 'stations': ['51463', 'ZWWW0']},
#  'data': [{'date': '2011-01-01',
#    'tavg': -14.9,
#    'tmin': -17.2,
#    'tmax': -11.9,
#    'prcp': 3.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-02',
#    'tavg': -21.1,
#    'tmin': -23.4,
#    'tmax': -17.2,
#    'prcp': 2.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-03',
#    'tavg': -25.2,
#    'tmin': -27.1,
#    'tmax': -22.3,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-04',
#    'tavg': -25.9,
#    'tmin': -28.1,
#    'tmax': -23.4,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-05',
#    'tavg': -23.6,
#    'tmin': -27.4,
#    'tmax': -21.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-06',
#    'tavg': -22.9,
#    'tmin': -25.3,
#    'tmax': -18.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-07',
#    'tavg': -23.2,
#    'tmin': -25.9,
#    'tmax': -20.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-08',
#    'tavg': -21.4,
#    'tmin': -25.3,
#    'tmax': -16.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-09',
#    'tavg': -23.7,
#    'tmin': -25.2,
#    'tmax': -20.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-10',
#    'tavg': -22.8,
#    'tmin': -26.5,
#    'tmax': -18.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 2.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-11',
#    'tavg': -20.4,
#    'tmin': -25.4,
#    'tmax': -12.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-12',
#    'tavg': -11.7,
#    'tmin': -16.5,
#    'tmax': -6.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-13',
#    'tavg': -13.8,
#    'tmin': -16.9,
#    'tmax': -10.1,
#    'prcp': 1.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-14',
#    'tavg': -20.1,
#    'tmin': -22.5,
#    'tmax': -16.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-15',
#    'tavg': -19.6,
#    'tmin': -22.5,
#    'tmax': -15.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-16',
#    'tavg': -17.6,
#    'tmin': -20.6,
#    'tmax': -13.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-17',
#    'tavg': -19.2,
#    'tmin': -22.8,
#    'tmax': -15.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-18',
#    'tavg': -15.9,
#    'tmin': -19.1,
#    'tmax': -10.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-19',
#    'tavg': -13.9,
#    'tmin': -18.2,
#    'tmax': -4.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-20',
#    'tavg': -19.3,
#    'tmin': -20.4,
#    'tmax': -16.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 2.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-21',
#    'tavg': -17.8,
#    'tmin': -20.4,
#    'tmax': -13.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-22',
#    'tavg': -19.5,
#    'tmin': -22.0,
#    'tmax': -16.5,
#    'prcp': 0.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-23',
#    'tavg': -16.8,
#    'tmin': -20.3,
#    'tmax': -9.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-24',
#    'tavg': -16.1,
#    'tmin': -19.1,
#    'tmax': -14.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-25',
#    'tavg': -13.5,
#    'tmin': -18.8,
#    'tmax': -9.3,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-26',
#    'tavg': -16.2,
#    'tmin': -17.6,
#    'tmax': -13.5,
#    'prcp': 2.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-27',
#    'tavg': -14.9,
#    'tmin': -19.5,
#    'tmax': -6.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-28',
#    'tavg': -19.6,
#    'tmin': -23.1,
#    'tmax': -15.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-29',
#    'tavg': -17.5,
#    'tmin': -19.2,
#    'tmax': -14.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-30',
#    'tavg': -18.4,
#    'tmin': -21.0,
#    'tmax': -14.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-01-31',
#    'tavg': -16.2,
#    'tmin': -19.4,
#    'tmax': -11.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-01',
#    'tavg': -13.9,
#    'tmin': -18.0,
#    'tmax': -8.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-02',
#    'tavg': -10.8,
#    'tmin': -13.3,
#    'tmax': -8.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-03',
#    'tavg': -10.7,
#    'tmin': -14.8,
#    'tmax': -8.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-04',
#    'tavg': -4.4,
#    'tmin': -9.6,
#    'tmax': -1.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-05',
#    'tavg': -6.9,
#    'tmin': -11.7,
#    'tmax': -2.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-06',
#    'tavg': -3.4,
#    'tmin': -5.0,
#    'tmax': -1.0,
#    'prcp': 2.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-07',
#    'tavg': -5.6,
#    'tmin': -6.9,
#    'tmax': -4.0,
#    'prcp': 1.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-08',
#    'tavg': -5.7,
#    'tmin': -7.4,
#    'tmax': -3.6,
#    'prcp': 2.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-09',
#    'tavg': -6.3,
#    'tmin': -8.4,
#    'tmax': 1.0,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-10',
#    'tavg': -5.6,
#    'tmin': -8.3,
#    'tmax': -2.0,
#    'prcp': 1.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-11',
#    'tavg': -5.1,
#    'tmin': -7.9,
#    'tmax': -0.8,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': 3.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-12',
#    'tavg': -8.7,
#    'tmin': -9.7,
#    'tmax': -6.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-13',
#    'tavg': -9.9,
#    'tmin': -11.2,
#    'tmax': -8.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-14',
#    'tavg': -6.7,
#    'tmin': -10.1,
#    'tmax': -1.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-15',
#    'tavg': -4.3,
#    'tmin': -8.0,
#    'tmax': -0.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-16',
#    'tavg': -8.5,
#    'tmin': -9.8,
#    'tmax': -5.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-17',
#    'tavg': -9.2,
#    'tmin': -9.9,
#    'tmax': -8.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-18',
#    'tavg': -8.9,
#    'tmin': -11.4,
#    'tmax': -6.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-19',
#    'tavg': -10.1,
#    'tmin': -12.6,
#    'tmax': -6.2,
#    'prcp': 0.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-20',
#    'tavg': -5.3,
#    'tmin': -8.1,
#    'tmax': -0.5,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-21',
#    'tavg': -5.8,
#    'tmin': -6.6,
#    'tmax': -3.3,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-22',
#    'tavg': -7.4,
#    'tmin': -8.9,
#    'tmax': -5.3,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-23',
#    'tavg': -8.8,
#    'tmin': -10.2,
#    'tmax': -7.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-24',
#    'tavg': -8.3,
#    'tmin': -9.1,
#    'tmax': -6.4,
#    'prcp': 4.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-25',
#    'tavg': -11.3,
#    'tmin': -13.1,
#    'tmax': -9.1,
#    'prcp': 2.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-26',
#    'tavg': -16.0,
#    'tmin': -17.5,
#    'tmax': -12.0,
#    'prcp': 0.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-27',
#    'tavg': -17.9,
#    'tmin': -20.0,
#    'tmax': -13.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-02-28',
#    'tavg': -17.3,
#    'tmin': -20.5,
#    'tmax': -12.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-01',
#    'tavg': -15.4,
#    'tmin': -18.5,
#    'tmax': -10.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-02',
#    'tavg': -13.7,
#    'tmin': -17.3,
#    'tmax': -10.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-03',
#    'tavg': -9.1,
#    'tmin': -15.0,
#    'tmax': -4.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-04',
#    'tavg': -8.6,
#    'tmin': -12.2,
#    'tmax': -4.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-05',
#    'tavg': -8.6,
#    'tmin': -12.2,
#    'tmax': -3.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-06',
#    'tavg': -7.4,
#    'tmin': -10.8,
#    'tmax': -3.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-07',
#    'tavg': -6.0,
#    'tmin': -10.5,
#    'tmax': -2.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-08',
#    'tavg': -5.0,
#    'tmin': -8.2,
#    'tmax': -0.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-09',
#    'tavg': -5.0,
#    'tmin': -8.5,
#    'tmax': -1.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 4.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-10',
#    'tavg': -1.2,
#    'tmin': -5.9,
#    'tmax': 5.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-11',
#    'tavg': 0.7,
#    'tmin': -6.4,
#    'tmax': 11.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-12',
#    'tavg': -5.6,
#    'tmin': -7.1,
#    'tmax': -1.9,
#    'prcp': 1.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-13',
#    'tavg': -7.8,
#    'tmin': -11.1,
#    'tmax': -3.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-14',
#    'tavg': -7.7,
#    'tmin': -12.5,
#    'tmax': -3.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-15',
#    'tavg': -6.3,
#    'tmin': -10.7,
#    'tmax': -0.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-16',
#    'tavg': -5.2,
#    'tmin': -7.0,
#    'tmax': 4.1,
#    'prcp': 15.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-17',
#    'tavg': -6.1,
#    'tmin': -11.7,
#    'tmax': 0.6,
#    'prcp': 1.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-18',
#    'tavg': -6.1,
#    'tmin': -10.7,
#    'tmax': 0.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-19',
#    'tavg': -7.7,
#    'tmin': -10.4,
#    'tmax': -3.3,
#    'prcp': 0.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-20',
#    'tavg': -10.7,
#    'tmin': -14.7,
#    'tmax': -6.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-21',
#    'tavg': -10.5,
#    'tmin': -15.4,
#    'tmax': -4.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-22',
#    'tavg': -9.5,
#    'tmin': -13.6,
#    'tmax': -4.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-23',
#    'tavg': -8.6,
#    'tmin': -12.7,
#    'tmax': -2.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-24',
#    'tavg': -5.6,
#    'tmin': -9.2,
#    'tmax': -0.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-25',
#    'tavg': -3.5,
#    'tmin': -7.7,
#    'tmax': 2.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-26',
#    'tavg': -1.0,
#    'tmin': -4.6,
#    'tmax': 2.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-27',
#    'tavg': 2.6,
#    'tmin': -1.5,
#    'tmax': 6.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-28',
#    'tavg': 2.7,
#    'tmin': -0.4,
#    'tmax': 6.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-29',
#    'tavg': 5.0,
#    'tmin': 3.1,
#    'tmax': 8.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-30',
#    'tavg': 5.1,
#    'tmin': 1.2,
#    'tmax': 9.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-03-31',
#    'tavg': 5.9,
#    'tmin': 2.6,
#    'tmax': 10.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-01',
#    'tavg': 6.7,
#    'tmin': 2.7,
#    'tmax': 11.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-02',
#    'tavg': 8.2,
#    'tmin': 3.7,
#    'tmax': 13.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-03',
#    'tavg': 8.1,
#    'tmin': 4.1,
#    'tmax': 12.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-04',
#    'tavg': -2.8,
#    'tmin': -4.0,
#    'tmax': 9.9,
#    'prcp': 25.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-05',
#    'tavg': -3.6,
#    'tmin': -6.0,
#    'tmax': -0.6,
#    'prcp': 1.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-06',
#    'tavg': 0.9,
#    'tmin': -5.2,
#    'tmax': 6.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-07',
#    'tavg': 5.3,
#    'tmin': 0.3,
#    'tmax': 10.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-08',
#    'tavg': 8.0,
#    'tmin': 3.4,
#    'tmax': 13.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-09',
#    'tavg': 11.3,
#    'tmin': 3.8,
#    'tmax': 19.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-10',
#    'tavg': 17.2,
#    'tmin': 13.6,
#    'tmax': 20.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-11',
#    'tavg': 14.4,
#    'tmin': 8.8,
#    'tmax': 19.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-12',
#    'tavg': 16.3,
#    'tmin': 12.2,
#    'tmax': 21.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-13',
#    'tavg': 17.5,
#    'tmin': 11.1,
#    'tmax': 23.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-14',
#    'tavg': 18.5,
#    'tmin': 11.5,
#    'tmax': 25.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-15',
#    'tavg': 19.4,
#    'tmin': 12.4,
#    'tmax': 26.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 122.0,
#    'wspd': 12.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-16',
#    'tavg': 20.3,
#    'tmin': 14.3,
#    'tmax': 26.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-17',
#    'tavg': 18.6,
#    'tmin': 13.6,
#    'tmax': 24.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-18',
#    'tavg': 15.4,
#    'tmin': 12.0,
#    'tmax': 21.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-19',
#    'tavg': 15.7,
#    'tmin': 11.8,
#    'tmax': 20.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-20',
#    'tavg': 17.0,
#    'tmin': 11.9,
#    'tmax': 22.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-21',
#    'tavg': 17.3,
#    'tmin': 13.3,
#    'tmax': 22.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-22',
#    'tavg': 17.0,
#    'tmin': 11.6,
#    'tmax': 24.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-23',
#    'tavg': 20.2,
#    'tmin': 13.4,
#    'tmax': 27.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-24',
#    'tavg': 18.2,
#    'tmin': 14.2,
#    'tmax': 25.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-25',
#    'tavg': 20.2,
#    'tmin': 14.9,
#    'tmax': 28.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-26',
#    'tavg': 19.9,
#    'tmin': 17.6,
#    'tmax': 25.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 298.0,
#    'wspd': 13.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-27',
#    'tavg': 18.3,
#    'tmin': 13.5,
#    'tmax': 24.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-28',
#    'tavg': 10.9,
#    'tmin': 7.1,
#    'tmax': 21.7,
#    'prcp': 19.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-29',
#    'tavg': 9.0,
#    'tmin': 3.3,
#    'tmax': 14.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-04-30',
#    'tavg': 12.9,
#    'tmin': 9.8,
#    'tmax': 17.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-01',
#    'tavg': 12.4,
#    'tmin': 9.0,
#    'tmax': 17.6,
#    'prcp': 9.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-02',
#    'tavg': 13.3,
#    'tmin': 8.3,
#    'tmax': 18.2,
#    'prcp': 12.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-03',
#    'tavg': 15.4,
#    'tmin': 10.0,
#    'tmax': 20.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-04',
#    'tavg': 17.1,
#    'tmin': 11.9,
#    'tmax': 23.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-05',
#    'tavg': 17.3,
#    'tmin': 13.7,
#    'tmax': 22.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-06',
#    'tavg': 17.9,
#    'tmin': 15.7,
#    'tmax': 20.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-07',
#    'tavg': 12.1,
#    'tmin': 5.8,
#    'tmax': 18.2,
#    'prcp': 1.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-08',
#    'tavg': 10.8,
#    'tmin': 8.8,
#    'tmax': 14.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-09',
#    'tavg': 9.6,
#    'tmin': 4.7,
#    'tmax': 14.3,
#    'prcp': 4.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-10',
#    'tavg': 11.8,
#    'tmin': 8.7,
#    'tmax': 15.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-11',
#    'tavg': 13.5,
#    'tmin': 7.7,
#    'tmax': 19.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-12',
#    'tavg': 16.6,
#    'tmin': 11.9,
#    'tmax': 22.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-13',
#    'tavg': 18.9,
#    'tmin': 15.3,
#    'tmax': 23.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-14',
#    'tavg': 20.6,
#    'tmin': 14.5,
#    'tmax': 26.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-15',
#    'tavg': 25.4,
#    'tmin': 17.6,
#    'tmax': 31.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-16',
#    'tavg': 24.7,
#    'tmin': 18.2,
#    'tmax': 31.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-17',
#    'tavg': 16.3,
#    'tmin': 11.6,
#    'tmax': 28.6,
#    'prcp': 4.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-18',
#    'tavg': 14.6,
#    'tmin': 11.9,
#    'tmax': 20.8,
#    'prcp': 0.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-19',
#    'tavg': 14.9,
#    'tmin': 11.1,
#    'tmax': 19.5,
#    'prcp': 0.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-20',
#    'tavg': 17.4,
#    'tmin': 11.8,
#    'tmax': 22.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-21',
#    'tavg': 16.1,
#    'tmin': 12.0,
#    'tmax': 21.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-22',
#    'tavg': 15.7,
#    'tmin': 12.1,
#    'tmax': 20.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-23',
#    'tavg': 14.5,
#    'tmin': 9.4,
#    'tmax': 20.0,
#    'prcp': 7.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-24',
#    'tavg': 17.5,
#    'tmin': 11.5,
#    'tmax': 23.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-25',
#    'tavg': 20.4,
#    'tmin': 13.4,
#    'tmax': 27.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-26',
#    'tavg': 22.5,
#    'tmin': 17.2,
#    'tmax': 27.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-27',
#    'tavg': 16.8,
#    'tmin': 14.4,
#    'tmax': 25.5,
#    'prcp': 2.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-28',
#    'tavg': 17.5,
#    'tmin': 11.8,
#    'tmax': 23.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-29',
#    'tavg': 20.1,
#    'tmin': 14.0,
#    'tmax': 27.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-30',
#    'tavg': 22.7,
#    'tmin': 15.5,
#    'tmax': 30.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-05-31',
#    'tavg': 24.4,
#    'tmin': 19.8,
#    'tmax': 28.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-01',
#    'tavg': 20.0,
#    'tmin': 16.2,
#    'tmax': 26.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-02',
#    'tavg': 18.8,
#    'tmin': 15.4,
#    'tmax': 21.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-03',
#    'tavg': 20.7,
#    'tmin': 16.9,
#    'tmax': 25.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-04',
#    'tavg': 24.4,
#    'tmin': 17.1,
#    'tmax': 31.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-05',
#    'tavg': 21.2,
#    'tmin': 18.5,
#    'tmax': 29.7,
#    'prcp': 0.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-06',
#    'tavg': 21.5,
#    'tmin': 16.4,
#    'tmax': 27.2,
#    'prcp': 3.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-07',
#    'tavg': 23.1,
#    'tmin': 19.2,
#    'tmax': 27.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-08',
#    'tavg': 24.2,
#    'tmin': 19.7,
#    'tmax': 28.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-09',
#    'tavg': 23.7,
#    'tmin': 19.5,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-10',
#    'tavg': 23.6,
#    'tmin': 20.4,
#    'tmax': 28.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-11',
#    'tavg': 24.9,
#    'tmin': 19.8,
#    'tmax': 30.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-12',
#    'tavg': 26.7,
#    'tmin': 20.9,
#    'tmax': 32.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-13',
#    'tavg': 25.1,
#    'tmin': 21.4,
#    'tmax': 31.6,
#    'prcp': 1.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-14',
#    'tavg': 22.2,
#    'tmin': 18.8,
#    'tmax': 25.6,
#    'prcp': 3.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-15',
#    'tavg': 21.7,
#    'tmin': 18.8,
#    'tmax': 26.2,
#    'prcp': 1.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-16',
#    'tavg': 23.8,
#    'tmin': 20.5,
#    'tmax': 28.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-17',
#    'tavg': 22.8,
#    'tmin': 17.9,
#    'tmax': 27.6,
#    'prcp': 3.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-18',
#    'tavg': 22.6,
#    'tmin': 19.7,
#    'tmax': 25.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-19',
#    'tavg': 19.8,
#    'tmin': 16.6,
#    'tmax': 22.9,
#    'prcp': 4.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-20',
#    'tavg': 22.9,
#    'tmin': 18.3,
#    'tmax': 26.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-21',
#    'tavg': 24.7,
#    'tmin': 18.6,
#    'tmax': 32.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 15.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-22',
#    'tavg': 22.3,
#    'tmin': 16.9,
#    'tmax': 26.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-23',
#    'tavg': 22.7,
#    'tmin': 19.0,
#    'tmax': 29.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-24',
#    'tavg': 23.8,
#    'tmin': 18.0,
#    'tmax': 30.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-25',
#    'tavg': 26.7,
#    'tmin': 20.3,
#    'tmax': 33.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-26',
#    'tavg': 27.6,
#    'tmin': 22.4,
#    'tmax': 34.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-27',
#    'tavg': 22.0,
#    'tmin': 18.0,
#    'tmax': 28.8,
#    'prcp': 1.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-28',
#    'tavg': 23.5,
#    'tmin': 18.4,
#    'tmax': 28.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-29',
#    'tavg': 23.2,
#    'tmin': 18.6,
#    'tmax': 28.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-06-30',
#    'tavg': 21.3,
#    'tmin': 16.6,
#    'tmax': 25.4,
#    'prcp': 4.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-01',
#    'tavg': 21.8,
#    'tmin': 18.6,
#    'tmax': 27.1,
#    'prcp': 0.2,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-02',
#    'tavg': 19.2,
#    'tmin': 14.7,
#    'tmax': 24.9,
#    'prcp': 37.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-03',
#    'tavg': 17.4,
#    'tmin': 12.9,
#    'tmax': 23.8,
#    'prcp': 16.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-04',
#    'tavg': 21.1,
#    'tmin': 15.6,
#    'tmax': 26.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-05',
#    'tavg': 22.4,
#    'tmin': 17.1,
#    'tmax': 26.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-06',
#    'tavg': 23.6,
#    'tmin': 17.9,
#    'tmax': 27.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-07',
#    'tavg': 24.5,
#    'tmin': 19.2,
#    'tmax': 29.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-08',
#    'tavg': 24.9,
#    'tmin': 21.3,
#    'tmax': 29.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-09',
#    'tavg': 24.7,
#    'tmin': 19.4,
#    'tmax': 29.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-10',
#    'tavg': 24.8,
#    'tmin': 19.8,
#    'tmax': 29.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-11',
#    'tavg': 26.3,
#    'tmin': 20.5,
#    'tmax': 32.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 191.0,
#    'wspd': 11.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-12',
#    'tavg': 28.7,
#    'tmin': 21.4,
#    'tmax': 35.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-13',
#    'tavg': 30.8,
#    'tmin': 23.9,
#    'tmax': 38.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-14',
#    'tavg': 28.8,
#    'tmin': 25.7,
#    'tmax': 37.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-15',
#    'tavg': 21.9,
#    'tmin': 18.6,
#    'tmax': 29.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-16',
#    'tavg': 19.8,
#    'tmin': 18.8,
#    'tmax': 22.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-17',
#    'tavg': 21.9,
#    'tmin': 16.8,
#    'tmax': 27.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-18',
#    'tavg': 25.0,
#    'tmin': 18.6,
#    'tmax': 31.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-19',
#    'tavg': 27.2,
#    'tmin': 21.6,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-20',
#    'tavg': 25.4,
#    'tmin': 23.2,
#    'tmax': 32.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-21',
#    'tavg': 22.0,
#    'tmin': 16.2,
#    'tmax': 27.9,
#    'prcp': 6.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-22',
#    'tavg': 24.7,
#    'tmin': 19.1,
#    'tmax': 30.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-23',
#    'tavg': 26.8,
#    'tmin': 21.0,
#    'tmax': 33.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-24',
#    'tavg': 29.3,
#    'tmin': 25.6,
#    'tmax': 33.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-25',
#    'tavg': 27.6,
#    'tmin': 23.6,
#    'tmax': 32.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 303.0,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-26',
#    'tavg': 25.3,
#    'tmin': 24.0,
#    'tmax': 30.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-27',
#    'tavg': 21.5,
#    'tmin': 15.6,
#    'tmax': 26.4,
#    'prcp': 4.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': 15.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-28',
#    'tavg': 24.6,
#    'tmin': 18.2,
#    'tmax': 31.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-29',
#    'tavg': 25.6,
#    'tmin': 19.0,
#    'tmax': 32.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-30',
#    'tavg': 27.7,
#    'tmin': 22.5,
#    'tmax': 34.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-07-31',
#    'tavg': 27.9,
#    'tmin': 23.3,
#    'tmax': 32.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-01',
#    'tavg': 25.7,
#    'tmin': 24.0,
#    'tmax': 30.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-02',
#    'tavg': 26.3,
#    'tmin': 21.6,
#    'tmax': 31.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 226.0,
#    'wspd': 11.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-03',
#    'tavg': 26.5,
#    'tmin': 22.7,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-04',
#    'tavg': 26.8,
#    'tmin': 21.3,
#    'tmax': 32.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-05',
#    'tavg': 28.0,
#    'tmin': 22.4,
#    'tmax': 34.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-06',
#    'tavg': 25.0,
#    'tmin': 19.5,
#    'tmax': 31.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-07',
#    'tavg': 27.0,
#    'tmin': 21.4,
#    'tmax': 33.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-08',
#    'tavg': 25.3,
#    'tmin': 23.3,
#    'tmax': 31.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-09',
#    'tavg': 20.2,
#    'tmin': 16.3,
#    'tmax': 24.4,
#    'prcp': 1.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-10',
#    'tavg': 21.2,
#    'tmin': 15.6,
#    'tmax': 25.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-11',
#    'tavg': 19.2,
#    'tmin': 16.6,
#    'tmax': 24.6,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-12',
#    'tavg': 20.4,
#    'tmin': 16.3,
#    'tmax': 25.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-13',
#    'tavg': 21.8,
#    'tmin': 18.0,
#    'tmax': 26.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-14',
#    'tavg': 22.8,
#    'tmin': 17.3,
#    'tmax': 26.3,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-15',
#    'tavg': 24.8,
#    'tmin': 19.3,
#    'tmax': 30.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-16',
#    'tavg': 26.3,
#    'tmin': 19.7,
#    'tmax': 33.1,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-17',
#    'tavg': 28.4,
#    'tmin': 23.9,
#    'tmax': 33.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 17.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-18',
#    'tavg': 28.5,
#    'tmin': 25.8,
#    'tmax': 32.8,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 161.0,
#    'wspd': 21.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-19',
#    'tavg': 27.3,
#    'tmin': 21.2,
#    'tmax': 33.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-20',
#    'tavg': 28.1,
#    'tmin': 21.8,
#    'tmax': 34.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-21',
#    'tavg': 24.9,
#    'tmin': 22.3,
#    'tmax': 31.5,
#    'prcp': 0.4,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-22',
#    'tavg': 19.6,
#    'tmin': 14.8,
#    'tmax': 24.1,
#    'prcp': 7.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-23',
#    'tavg': 22.0,
#    'tmin': 16.1,
#    'tmax': 28.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-24',
#    'tavg': 25.8,
#    'tmin': 19.7,
#    'tmax': 32.5,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-25',
#    'tavg': 27.0,
#    'tmin': 20.7,
#    'tmax': 35.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-26',
#    'tavg': 24.6,
#    'tmin': 19.2,
#    'tmax': 32.3,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 13.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-27',
#    'tavg': 16.8,
#    'tmin': 12.7,
#    'tmax': 24.9,
#    'prcp': 43.9,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-28',
#    'tavg': 14.2,
#    'tmin': 12.4,
#    'tmax': 15.5,
#    'prcp': 0.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-29',
#    'tavg': 14.5,
#    'tmin': 12.9,
#    'tmax': 16.4,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-30',
#    'tavg': 14.8,
#    'tmin': 11.1,
#    'tmax': 19.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-08-31',
#    'tavg': 15.8,
#    'tmin': 11.6,
#    'tmax': 19.7,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-01',
#    'tavg': 16.2,
#    'tmin': 13.6,
#    'tmax': 20.2,
#    'prcp': 0.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-02',
#    'tavg': 18.2,
#    'tmin': 13.3,
#    'tmax': 23.7,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2011-09-03',
#    'tavg': 20.0,
#    'tmin': 15.2,
#    'tmax': 25.9,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.0,
#    'wpgt': None,
# ...
#   {'date': '2013-07-07',
#    'tavg': 20.4,
#    'tmin': 15.7,
#    'tmax': 27.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': 275.0,
#    'wspd': 11.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-08',
#    'tavg': 19.0,
#    'tmin': 16.4,
#    'tmax': 25.0,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-09',
#    'tavg': 21.4,
#    'tmin': 16.5,
#    'tmax': 28.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-10',
#    'tavg': 23.8,
#    'tmin': 16.6,
#    'tmax': 28.8,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-11',
#    'tavg': 23.8,
#    'tmin': 19.1,
#    'tmax': 32.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-12',
#    'tavg': 23.1,
#    'tmin': 18.8,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-13',
#    'tavg': 25.2,
#    'tmin': 19.5,
#    'tmax': 33.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-14',
#    'tavg': 27.8,
#    'tmin': 21.2,
#    'tmax': 35.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-15',
#    'tavg': 22.7,
#    'tmin': 17.0,
#    'tmax': 30.0,
#    'prcp': 11.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-16',
#    'tavg': 22.8,
#    'tmin': 15.7,
#    'tmax': 29.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-17',
#    'tavg': 24.6,
#    'tmin': 19.1,
#    'tmax': 31.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-18',
#    'tavg': 24.3,
#    'tmin': 20.1,
#    'tmax': 33.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-19',
#    'tavg': 21.8,
#    'tmin': 22.0,
#    'tmax': 30.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-20',
#    'tavg': 23.8,
#    'tmin': 18.2,
#    'tmax': 31.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-21',
#    'tavg': 25.9,
#    'tmin': 19.2,
#    'tmax': 32.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-22',
#    'tavg': 20.9,
#    'tmin': 20.0,
#    'tmax': 28.0,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-23',
#    'tavg': 22.3,
#    'tmin': 16.8,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-24',
#    'tavg': 23.1,
#    'tmin': 17.5,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-25',
#    'tavg': 22.8,
#    'tmin': 18.3,
#    'tmax': 30.0,
#    'prcp': 0.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-26',
#    'tavg': 24.3,
#    'tmin': 17.7,
#    'tmax': 31.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-27',
#    'tavg': 26.7,
#    'tmin': 19.6,
#    'tmax': 34.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-28',
#    'tavg': 27.0,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 3.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-29',
#    'tavg': 25.8,
#    'tmin': 22.0,
#    'tmax': 33.0,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-30',
#    'tavg': 23.6,
#    'tmin': 16.9,
#    'tmax': 31.0,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-07-31',
#    'tavg': 25.2,
#    'tmin': 20.1,
#    'tmax': 32.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-01',
#    'tavg': 26.6,
#    'tmin': 20.2,
#    'tmax': 34.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-02',
#    'tavg': 30.5,
#    'tmin': 21.9,
#    'tmax': 38.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-03',
#    'tavg': 26.7,
#    'tmin': 23.0,
#    'tmax': 36.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-04',
#    'tavg': 23.1,
#    'tmin': 16.5,
#    'tmax': 32.0,
#    'prcp': 6.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-05',
#    'tavg': 24.3,
#    'tmin': 23.0,
#    'tmax': 31.0,
#    'prcp': 5.1,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-06',
#    'tavg': 26.1,
#    'tmin': 20.8,
#    'tmax': 33.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-07',
#    'tavg': 27.4,
#    'tmin': 21.7,
#    'tmax': 35.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': 136.0,
#    'wspd': 10.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-08',
#    'tavg': 22.1,
#    'tmin': 23.0,
#    'tmax': 28.0,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-09',
#    'tavg': 23.7,
#    'tmin': 21.0,
#    'tmax': 31.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-10',
#    'tavg': 24.9,
#    'tmin': 19.3,
#    'tmax': 32.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-11',
#    'tavg': 22.8,
#    'tmin': 22.0,
#    'tmax': 31.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-12',
#    'tavg': 22.4,
#    'tmin': 18.5,
#    'tmax': 28.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.5,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-13',
#    'tavg': 19.9,
#    'tmin': 17.7,
#    'tmax': 26.0,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-14',
#    'tavg': 20.2,
#    'tmin': 20.0,
#    'tmax': 26.0,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-15',
#    'tavg': 20.6,
#    'tmin': 14.9,
#    'tmax': 28.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-16',
#    'tavg': 20.5,
#    'tmin': 16.8,
#    'tmax': 28.0,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-17',
#    'tavg': 18.9,
#    'tmin': 16.0,
#    'tmax': 26.0,
#    'prcp': 1.8,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-18',
#    'tavg': 17.4,
#    'tmin': 13.7,
#    'tmax': 24.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-19',
#    'tavg': 20.4,
#    'tmin': 14.2,
#    'tmax': 28.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-20',
#    'tavg': 22.0,
#    'tmin': 15.7,
#    'tmax': 29.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-21',
#    'tavg': 24.2,
#    'tmin': 18.9,
#    'tmax': 31.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-22',
#    'tavg': 23.6,
#    'tmin': 22.0,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-23',
#    'tavg': 25.8,
#    'tmin': 19.4,
#    'tmax': None,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-24',
#    'tavg': 27.8,
#    'tmin': 20.8,
#    'tmax': 36.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-25',
#    'tavg': 19.8,
#    'tmin': 18.0,
#    'tmax': 28.0,
#    'prcp': 4.6,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-26',
#    'tavg': 21.1,
#    'tmin': 15.7,
#    'tmax': 29.0,
#    'prcp': 1.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-27',
#    'tavg': 21.5,
#    'tmin': 17.1,
#    'tmax': 28.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-28',
#    'tavg': 23.2,
#    'tmin': 15.9,
#    'tmax': 31.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-29',
#    'tavg': 26.2,
#    'tmin': 18.1,
#    'tmax': 35.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-30',
#    'tavg': 17.8,
#    'tmin': 12.0,
#    'tmax': 27.0,
#    'prcp': 14.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 14.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-08-31',
#    'tavg': 13.4,
#    'tmin': 9.4,
#    'tmax': 19.0,
#    'prcp': 0.5,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-01',
#    'tavg': 15.3,
#    'tmin': 10.4,
#    'tmax': 22.0,
#    'prcp': 0.3,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-02',
#    'tavg': 17.1,
#    'tmin': 11.8,
#    'tmax': 22.2,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-03',
#    'tavg': 19.0,
#    'tmin': 12.9,
#    'tmax': 27.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-04',
#    'tavg': 20.9,
#    'tmin': 13.9,
#    'tmax': 29.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 9.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-05',
#    'tavg': 22.7,
#    'tmin': 16.4,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': 189.0,
#    'wspd': 10.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-06',
#    'tavg': 22.4,
#    'tmin': 18.8,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-07',
#    'tavg': 22.3,
#    'tmin': 17.5,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-08',
#    'tavg': 21.3,
#    'tmin': 19.0,
#    'tmax': 28.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-09',
#    'tavg': 22.3,
#    'tmin': 15.0,
#    'tmax': 30.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.0,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-10',
#    'tavg': 23.9,
#    'tmin': 17.0,
#    'tmax': 34.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-11',
#    'tavg': 20.9,
#    'tmin': 17.2,
#    'tmax': 28.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-12',
#    'tavg': 21.6,
#    'tmin': 18.0,
#    'tmax': 32.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 11.6,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-13',
#    'tavg': 18.3,
#    'tmin': None,
#    'tmax': None,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': None,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-14',
#    'tavg': 18.9,
#    'tmin': 13.9,
#    'tmax': 24.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-15',
#    'tavg': 15.6,
#    'tmin': 15.0,
#    'tmax': 21.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-16',
#    'tavg': 13.9,
#    'tmin': 11.0,
#    'tmax': 23.0,
#    'prcp': 12.7,
#    'snow': None,
#    'wdir': None,
#    'wspd': 12.3,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-17',
#    'tavg': 13.0,
#    'tmin': 9.1,
#    'tmax': 19.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 5.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-18',
#    'tavg': 15.4,
#    'tmin': 11.0,
#    'tmax': 23.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.4,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-19',
#    'tavg': 16.2,
#    'tmin': 11.0,
#    'tmax': 23.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-20',
#    'tavg': 14.6,
#    'tmin': 13.0,
#    'tmax': 22.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-21',
#    'tavg': 6.8,
#    'tmin': 6.0,
#    'tmax': 13.0,
#    'prcp': 0.0,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.7,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-22',
#    'tavg': 8.1,
#    'tmin': 4.4,
#    'tmax': 15.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 6.9,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-23',
#    'tavg': 12.7,
#    'tmin': 3.6,
#    'tmax': 20.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 10.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-24',
#    'tavg': 15.6,
#    'tmin': 9.7,
#    'tmax': 22.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.8,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-25',
#    'tavg': 19.7,
#    'tmin': 10.1,
#    'tmax': 23.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 8.1,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   {'date': '2013-09-26',
#    'tavg': 20.9,
#    'tmin': 12.0,
#    'tmax': 28.0,
#    'prcp': None,
#    'snow': None,
#    'wdir': None,
#    'wspd': 7.2,
#    'wpgt': None,
#    'pres': None,
#    'tsun': None},
#   ...]}

# %%
# Out:
# {'meta': {'generated': '2023-07-07 01:47:17', 'stations': []}, 'data': []}

# %%
# Out:
# {'meta': {'generated': '2023-07-07 01:47:12', 'stations': ['38627']},
#  'data': []}

# %%
#extract data
la_data = extract_temperature_data(la)
nyc_data = extract_temperature_data(nyc)
chi_data = extract_temperature_data(chi)
detroit_data = extract_temperature_data(detroit)
columbus_oh_data = extract_temperature_data(columbus)
philly_data = extract_temperature_data(philly)
newark_data = extract_temperature_data(newark)
houston_data = extract_temperature_data(houston)
indianapolis_data = extract_temperature_data(indianapolis)
milwaukee_data = extract_temperature_data(milwaukee)

# %%
chi_data

# %%
# Dictionary to hold all datasets to export
datasets = {
    'la': la_data,
    'nyc': nyc_data,
    'chi': chi_data,
    'detroit': detroit_data,
    'columbus_oh': columbus_oh_data,
    'philly': philly_data,
    'newark': newark_data,
    'houston': houston_data,
    'indianapolis': indianapolis_data,
    'milwaukee': milwaukee_data
}

# %%
export_datasets(datasets)
